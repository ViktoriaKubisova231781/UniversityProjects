# %%
import pandas as pd# importing the dataset 
df_train = pd.read_csv(r"C:\Users\ronle\Desktop\BUAS\Y2C\datasets\kaggle\train.txt", header =None, sep =';', names = ['Input','Sentiment'], encoding='utf-8')

df_test = pd.read_csv(r"C:\Users\ronle\Desktop\BUAS\Y2C\datasets\kaggle\test.txt", header = None, sep =';', names = ['Input','Sentiment'],encoding='utf-8')

df_val = pd.read_csv(r"C:\Users\ronle\Desktop\BUAS\Y2C\datasets\kaggle\val.txt", header=None,sep=';', names=['Input','Sentiment'], encoding='utf-8')

print(df_train.shape)
# Out:
# (16000, 2)
