# %%
# Change path to parent directory (..)
import os
os.chdir("..")

# %%
# !python src/pipeline.py --url "https://www.youtube.com/watch?v=ZDsfeIyjZUM" --filename "top_models" --transcription assemblyAI
# Out:
# Step 1 - Downloading YouTube audio...
# ...
# Loading checkpoint shards: 100%|██████████| 3/3 [00:08<00:00,  2.85s/it]
#
# ...
# Translating Sentences to Polish: 100%|██████████| 861/861 [44:28<00:00,  3.10s/sentence]
#
# ...
# Loading checkpoint shards: 100%|██████████| 3/3 [00:11<00:00,  3.68s/it]
#
# ...
# Translating Sentences to English: 100%|██████████| 861/861 [52:44<00:00,  3.67s/sentence]
#
# ...
# Generating predictions: 100%|███████████████████████████████████████████████████████████| 54/54 [02:05<00:00,  2.32s/it]
# Audio file saved at: x:\University\2024-25c-fai2-adsai-group-group21\task 11 - Complete Pipeline\data\youtube_audio\top_models.mp3
# YouTube audio downloaded successfully!
# Step 2 - Transcribing audio...
# Transcribing x:\University\2024-25c-fai2-adsai-group-group21\task 11 - Complete Pipeline\data\youtube_audio\top_models.mp3...
# Saving transcript to x:\University\2024-25c-fai2-adsai-group-group21\task 11 - Complete Pipeline\data\transcription\transcribed_data_assemblyAI.xlsx...
# ...
