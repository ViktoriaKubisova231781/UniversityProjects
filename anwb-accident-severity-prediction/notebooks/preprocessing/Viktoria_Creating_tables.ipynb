# %% [markdown]
# # Creating tables in our warehouse

# %%
import psycopg2
import pandas as pd

# %%
db_params = {
    'host': '194.171.191.226',
    'port': '6379',
    'database': 'postgres',
    'user': 'group15',
    'password': 'blockd_2024group15_73'
}

# %%
conn_psycopg2 = psycopg2.connect(**db_params)
cursor = conn_psycopg2.cursor()

# %% [markdown]
# ##  Accident data 17-23

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.accident_data_17_23 AS
        SELECT * FROM data_lake.accident_data_17_23;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.accident_data_17_23;
'''

cursor.execute(query)

# Fetch all rows
new_accident_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
new_accidents = pd.DataFrame(new_accident_rows, columns=column_names)

display(new_accidents)
# Out:
#       Year Accident severity municipality         town  \
# 0     2017             Fatal        Breda        BREDA
# 1     2017             Fatal        Breda        BREDA
# 2     2017             Fatal        Breda        BREDA
# 3     2017           Injured        Breda        BAVEL
# 4     2017           Injured        Breda        BAVEL
# ...    ...               ...          ...          ...
# 6897  2023             Fatal        Breda        BREDA
# 6898  2023             Fatal        Breda        BREDA
# 6899  2023             Fatal        Breda        BREDA
# 6900  2023             Fatal        Breda  PRINSENBEEK
# 6901  2023             Fatal        Breda    ULVENHOUT
#
#      First Mode of Transport Second mode of Transport   Area Type  \
# 0                        Car               Pedestrian  Urban area
# 1                      Lorry                    Other  Urban area
# 2                      Lorry                    Other  Urban area
# ...

# %% [markdown]
# ## Safe driving

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.safe_driving AS
        SELECT * FROM data_lake.safe_driving;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.safe_driving;
'''

cursor.execute(query)

# Fetch all rows
safe_driving_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
safe_driving = pd.DataFrame(safe_driving_rows, columns=column_names)

display(safe_driving)
# Out:
#           eventid             event_start               event_end  \
# 0       114074654 2023-04-20 15:22:52.800 2023-04-20 15:22:54.800
# 1       114106469 2023-04-20 07:43:37.500 2023-04-20 07:43:38.800
# 2       114224520 2023-04-20 15:34:16.400 2023-04-20 15:34:25.000
# 3       114230868 2023-04-20 10:02:42.700 2023-04-20 10:02:44.100
# 4       114263402 2023-04-20 17:22:39.700 2023-04-20 17:22:41.200
# ...           ...                     ...                     ...
# 964483  114224185 2023-04-20 15:03:18.900 2023-04-20 15:03:23.300
# 964484  114192172 2023-04-20 16:38:37.300 2023-04-20 16:38:37.900
# 964485  114228627 2023-04-20 14:52:28.000 2023-04-20 14:52:44.000
# 964486  114212870 2023-04-20 14:34:38.000 2023-04-20 14:34:39.300
# 964487  114243902 2023-04-20 18:34:10.900 2023-04-20 18:34:12.900
#
#         duration_seconds  latitude  longitude   speed_kmh  end_speed_kmh  \
# 0                    2.0  51.59626   4.750160   30.067245      23.846440
# ...

# %% [markdown]
# ## Temperature

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.temperature AS
        SELECT * FROM data_lake.temperature;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.temperature;
'''

cursor.execute(query)

# Fetch all rows
temperature_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
temperature = pd.DataFrame(temperature_rows, columns=column_names)

display(temperature)
# Out:
#                        dtg LOCATION                   NAME  latitude  \
# 0      2017-01-03 03:20:00  350_T_a  Gilze-Rijen locatie A    51.565
# 1      2017-01-03 03:30:00  350_T_a  Gilze-Rijen locatie A    51.565
# 2      2017-01-03 03:40:00  350_T_a  Gilze-Rijen locatie A    51.565
# 3      2017-01-03 03:50:00  350_T_a  Gilze-Rijen locatie A    51.565
# 4      2017-01-03 04:00:00  350_T_a  Gilze-Rijen locatie A    51.565
# ...                    ...      ...                    ...       ...
# 954283 2017-01-03 02:30:00  350_T_a  Gilze-Rijen locatie A    51.565
# 954284 2017-01-03 02:40:00  350_T_a  Gilze-Rijen locatie A    51.565
# 954285 2017-01-03 02:50:00  350_T_a  Gilze-Rijen locatie A    51.565
# 954286 2017-01-03 03:00:00  350_T_a  Gilze-Rijen locatie A    51.565
# 954287 2017-01-03 03:10:00  350_T_a  Gilze-Rijen locatie A    51.565
#
#         longitude  altitude  u_bool_10  t_dryb_10  tn_10cm_past_6h_10  \
# ...

# %% [markdown]
# ## Wind

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.wind AS
        SELECT * FROM data_lake.wind;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.wind;
'''

cursor.execute(query)

# Fetch all rows
wind_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
wind = pd.DataFrame(wind_rows, columns=column_names)

display(wind)
# Out:
#                         dtg LOCATION                   NAME  latitude  \
# 0       2013-04-22 17:50:00  350_W_a  Gilze-Rijen locatie A    51.565
# 1       2013-04-22 18:00:00  350_W_a  Gilze-Rijen locatie A    51.565
# 2       2013-04-22 18:10:00  350_W_a  Gilze-Rijen locatie A    51.565
# 3       2013-04-22 18:20:00  350_W_a  Gilze-Rijen locatie A    51.565
# 4       2013-04-22 18:30:00  350_W_a  Gilze-Rijen locatie A    51.565
# ...                     ...      ...                    ...       ...
# 1098832 2013-04-22 17:00:00  350_W_a  Gilze-Rijen locatie A    51.565
# 1098833 2013-04-22 17:10:00  350_W_a  Gilze-Rijen locatie A    51.565
# 1098834 2013-04-22 17:20:00  350_W_a  Gilze-Rijen locatie A    51.565
# 1098835 2013-04-22 17:30:00  350_W_a  Gilze-Rijen locatie A    51.565
# 1098836 2013-04-22 17:40:00  350_W_a  Gilze-Rijen locatie A    51.565
#
#          longitude  altitude  ff_10m_10  dd_10  ddn_10  dd_std_10  ddx_10  \
# ...

# %% [markdown]
# ## Precipitation

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.precipitation AS
        SELECT * FROM data_lake.precipitation;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.precipitation;
'''

cursor.execute(query)

# Fetch all rows
precipitation_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
precipitation = pd.DataFrame(precipitation_rows, columns=column_names)

display(precipitation)
# Out:
#                         dtg LOCATION                     NAME  latitude  \
# 0       2011-12-28 10:10:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 1       2011-12-28 10:20:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 2       2011-12-28 10:30:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 3       2011-12-28 10:40:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 4       2011-12-28 10:50:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# ...                     ...      ...                      ...       ...
# 1098427 2011-12-28 09:20:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 1098428 2011-12-28 09:30:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 1098429 2011-12-28 09:40:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 1098430 2011-12-28 09:50:00  350_R_a  Gilze-Rijen locatie 10t    51.565
# 1098431 2011-12-28 10:00:00  350_R_a  Gilze-Rijen locatie 10t    51.565
#
#          longitude  altitude  dr_pws_10  dr_regenm_10  ww_cor_10  ri_pws_10  \
# ...

# %% [markdown]
# ## Greenery

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.greenery AS
        SELECT * FROM data_lake.greenery;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.greenery;
'''

cursor.execute(query)

# Fetch all rows
greenery_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
greenery = pd.DataFrame(greenery_rows, columns=column_names)

display(greenery)
# Out:
#             _id                                             _key namespace  \
# 0         67650  NL.IMGeo.G0718.e6d426485c554192aa662a98db213e33  NL.IMGeo
# 1         67638  NL.IMGeo.G0718.9033f775c728495fb95f0441fa4e1cfa  NL.IMGeo
# 2         67609  NL.IMGeo.G0718.fa4855eed1864ad8b4535623a8939910  NL.IMGeo
# 3         67610  NL.IMGeo.G0718.fc68349b2bdd449783de27c837fbc14c  NL.IMGeo
# 4         67596  NL.IMGeo.G0718.b8d7be0936b441eab357c819ce76c926  NL.IMGeo
# ...         ...                                              ...       ...
# 888114  1174144  NL.IMGeo.G0599.16fd01755eba4cac9e050210a7e24119  NL.IMGeo
# 888115  1173983  NL.IMGeo.G0599.16fd01755eba0cac9e050210a7e24119  NL.IMGeo
# 888116  1174116  NL.IMGeo.G0599.16fd017887e04cac9e050210a7e24119  NL.IMGeo
# 888117  1173487  NL.IMGeo.G0599.16fd017884e90cac9e050210a7e24119  NL.IMGeo
# 888118  1173437  NL.IMGeo.G0599.16fd01755e61acac9e050210a7e24119  NL.IMGeo
#
# ...

# %% [markdown]
# ## Breda road

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.breda_road AS
        SELECT * FROM data_lake.breda_road;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.breda_road;
'''

cursor.execute(query)

# Fetch all rows
breda_road_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
breda_road = pd.DataFrame(breda_road_rows, columns=column_names)

display(breda_road)
# Out:
#            _id                                             _key namespace  \
# 0      2533831  NL.IMGeo.G0758.e9413581e36a4be7a7f4531e40991d91  NL.IMGeo
# 1      2533833  NL.IMGeo.G0758.7fe9a4d6585e4bd0be6ef6110cf7ee4f  NL.IMGeo
# 2      2535891  NL.IMGeo.G0758.ce3ba43543dd477bbe585e80de96c26b  NL.IMGeo
# 3      2535884  NL.IMGeo.G0758.8a18a26fbc7d4ca0bb5754ef8dedd685  NL.IMGeo
# 4      2533830  NL.IMGeo.G0758.b092d73c56ff4afb81b315a5625c08c2  NL.IMGeo
# ...        ...                                              ...       ...
# 75893  2663538  NL.IMGeo.G0826.0928f986dcd9a9f9e0534a07c00a7619  NL.IMGeo
# 75894  2663541  NL.IMGeo.G0826.0928f986e90ba9f9e0534a07c00a7619  NL.IMGeo
# 75895  2663539  NL.IMGeo.G0826.0928f986e1e2a9f9e0534a07c00a7619  NL.IMGeo
# 75896  2663579  NL.IMGeo.G0826.0928f986e214a9f9e0534a07c00a7619  NL.IMGeo
# 75897  2663543  NL.IMGeo.G0826.0928f986ea22a9f9e0534a07c00a7619  NL.IMGeo
#
#                                      lokaalid objectbegintijd objecteindtijd  \
# ...

# %% [markdown]
# ## Accidents

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.accidents AS
        SELECT * FROM data_lake.accidents;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.accidents;
'''

cursor.execute(query)

# Fetch all rows
accidents_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
accidents = pd.DataFrame(accidents_rows, columns=column_names)

display(accidents)
# Out:
#            vkl_nummer  regnummer pvopgem datum_vkl dag_code mnd_nummer  \
# 0        320070889389  07-091381
# 1        320070889434  07-574474
# 2        320070889450  07-081452
# 3        320070889469  07-078227
# 4        320070889493  07-081964
# ...               ...        ...     ...       ...      ...        ...
# 2336967  320070889135  07-050100
# 2336968  320070889346  07-574359
# 2336969  320070889354  07-574352
# 2336970  320070889362  07-574323
# 2336971  320070889370  07-572488
#
#          jaar_vkl tijdstip uur ddl_id  ...       pve_naam  \
# 0            2007                      ...  Noord-Brabant
# 1            2007                      ...  Noord-Brabant
# 2            2007                      ...        Zeeland
# 3            2007                      ...        Zeeland
# 4            2007                      ...        Zeeland
# ...           ...      ...  ..    ...  ...            ...
# 2336967      2007                      ...  Noord-Holland
# ...

# %% [markdown]
# ## Gridcodes

# %%
# Define the SQL query to create the new table
create_table_query = '''
    CREATE TABLE IF NOT EXISTS group15_warehouse.gridcodes AS
        SELECT * FROM data_lake.gridcodes;
'''
cursor.execute(create_table_query)
conn_psycopg2.commit()

# %%
# Execute SQL query to fetch distinct category types
query = '''
    SELECT * 
    FROM group15_warehouse.gridcodes;
'''

cursor.execute(query)

# Fetch all rows
gridcodes_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
gridcodes = pd.DataFrame(gridcodes_rows, columns=column_names)

display(gridcodes)
# Out:
#          cbs_code   area          x          y   buurtcode  \
# 0              -1     -1       NULL       NULL    Onbekend
# 1      E1055N4032  10003  4.6732125  51.615944  BU07580909
# 2      E1055N4033  10003  4.6731982  51.616844  BU07580909
# 3      E1055N4034  10003  4.6731839  51.617741  BU07580909
# 4      E1055N4035  10003  4.6731701  51.618641  BU07580909
# ...           ...    ...        ...        ...         ...
# 13264  E1055N4027  10003  4.6732831   51.61145  BU07580909
# 13265  E1055N4028  10003  4.6732693   51.61235  BU07580909
# 13266  E1055N4029  10003   4.673255  51.613247  BU07580909
# 13267  E1055N4030  10003  4.6732407  51.614147  BU07580909
# 13268  E1055N4031  10003  4.6732268  51.615047  BU07580909
#
#                       buurtnaam
# 0                      Onbekend
# 1      Buitengebied Prinsenbeek
# 2      Buitengebied Prinsenbeek
# 3      Buitengebied Prinsenbeek
# 4      Buitengebied Prinsenbeek
# ...                         ...
# ...

# %% [markdown]
# ## Closing the connection

# %%
# Close the cursor and connection
conn_psycopg2.close()
cursor.close()
