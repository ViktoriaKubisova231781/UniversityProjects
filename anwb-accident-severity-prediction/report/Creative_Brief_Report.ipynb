# %% [markdown]
# # Jupyter Notebook Template for Block 1D

# %% [markdown]
# Please insert your name and the team number in the following cell:

# %% [markdown]
# #### Student Name: Viktória Kubišová
# #### Team No.: Team 15

# %% [markdown]
# This template is meant to help you provide the related evidence for ILOs 3.0 to 7.0 of block 1D-2023-2024. Please don't change the order of the cells. You can still add as many cells as you want in the designated place to provide evidence for each ILO. To remind you about the criteria of each ILO, the criteria for each ILO are provided in each section. We hope that you find immense enjoyment and fulfillment as you embark on your project journey.

# %% [markdown]
# ## ILO 3.0: Legal Framework
#
# The student demonstrates knowledge of relevant legal frameworks by providing evidence of legal decision-making while working with data.
#
# Demonstrates the basic knowledge of european legal frameworks governing AI by providing evidence of legal decision-making while working with (privacy-sensitive) data:
#
# - **Poor**: The individual contribution to the project is merely documented, rather than reflected upon. There is no mention of releveant legal frameworks and the group assessment is hardly mentioned.
#
# - **Insufficient**: The student is able to individually identify the level of risk associated with their AI system and explain it clearly.  The group collaboratively identifies the level of risk associated with the developed AI system. The explanation is superficial and meeting all criteria in poor.
#
# - **Sufficient**: The individual reflection on the legality of the individual contributions made to the project is thorough. The group legal assessment of the project is based on relevant  frameworks provided during the module. The legal requirements and obligations that are vital to address for the development of  AI system are identified. The legal requirements and obligations that don’t need to be addressed for the development of AI system are identified. And meeting all criteria in insufficient.
#
# - **Good**: The relevance of legal requirements and obligations included in the group assessment for this project is explained. The reasoning for not including certain legal requirements and obligations in the assessment is justified. Argumentation for including and excluding legal requirements and obligations for the assessment is based on important facts, details, examples, and explanations from multiple authoritative sources and data. And meeting all criteria in sufficient.
#
# - **Excellent**: The student provides evidence and explanations of legal decision-making for obligations within the group assessment (where possible). And meeting all criteria in good.

# %% [markdown]
# ### Task 3.1 - Risk assessment of your initial proposal (Idividual Task 1)
#
# Based on the content covered during the block (Week 3, Thursday), assess the level of risk associated with the AI system proposed in your project proposal presentation.
#
# This evidence is related to **insufficient** criteria.

# %% [markdown]
# Based on the study material and the guidelines provided by the EU AI Act, I concluded that our project idea of the AI system developed for predicting traffic accident severity and identifying high-risk intersections in Breda falls into the 'High-risk' category due to its potential impact on safety and livelihood.
# High-Risk AI System Classification Explanation
#
# **Social Impact and Public Safety:**
# - The AI system influences road safety measures, impacting law enforcement and emergency service actions, which are crucial for public safety.
# - The system's predictive capabilities can significantly affect how and where resources are allocated, potentially impacting the safety and well-being of residents and visitors in Breda.
# - Since our project aims to predict accident severity preemptively, which could significantly influence driver behavior.
#
# **Essential Services and Infrastructure:**
# - The AI system manages essential public infrastructure by predicting accident hotspots and severities, facilitating targeted interventions and efficient mobilization of emergency services.
#
# **Law Enforcement:**
# - The system assists in law enforcement by providing data-driven insights for proactive accident prevention and efficient response strategies, affecting public safety directly.
#
# In general, this AI system directly impacts road safety, which is critical for human wellbeing. Providing real-time alerts to users can shape their behavior and decisions, potentially leading to serious consequences if predictions are inaccurate. Inaccurate predictions could result in unintended outcomes, increasing rather than reducing accident risks.
#
# To accurately assess the risks associated with our AI system, understanding its impact on public safety and accident-involved individuals is crucial. Continuous monitoring and evaluation of our AI model's performance and impact allow us to identify risks and vulnerabilities. This iterative process enables us to adapt and improve our model, minimizing potential risks.

# %%
# Make sure to include your answers to the project proposal presentation.
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Final_Proposal_Presentation_Team_15.pdf

# %% [markdown]
# ### Task 3.2 - Explanation of the risk (Individual Task 2)
#
# Based on the content learned during the block (Week 3, Thursday), **explain and justify** the level of risk associated with the AI system you will individually propose during your project proposal presentation.
#
# Outline the legal obligations that must be followed. If no legal obligations apply to your AI system, please provide the reasoning.
#
# Additionally, explain your approach for addressing legal obligations during the implementation process of your AI system.
#
# This evidence is related to **poor** and **insufficient** criteria.

# %% [markdown]
# **The AI system is categorized as high-risk due to its predictions potentially impacting safety measures, emergency services ditribution and law enforcement actions. Thorough explanation and reasoning is provided in the section above.**
#
# ### Legal Obligations Under the EU AI Act
# The SmartAccidentPredict project must adhere to several legal obligations specified in the EU AI Act. Below are the relevant titles and articles, along with our approach to addressing these legal obligations during the implementation process:
#
# #### Title II: Prohibited AI Practices (Article 5)
# **Obligations:**
# - Ensure the AI system does not engage in manipulative behavior that exploits vulnerabilities of specific groups (e.g., children).
# - Avoid any form of social scoring that categorizes individuals based on personal traits.
# - Do not implement biometric identification or mass surveillance practices without proper consent.
#
# **Approach:**
# - The AI system will strictly focus on predicting traffic accident severity and identifying high-risk intersections, ensuring it does not manipulate behavior or exploit vulnerabilities.
# - The system will not engage in social scoring or track individuals, maintaining ethical standards and respecting user privacy.
# - There will be no use of biometric identification or mass surveillance techniques in the system.
#
# #### Title III: High-Risk AI Systems (Articles 6-15; Article 16)
# **Obligations:**
# - Classify the AI system correctly as high-risk and ensure it meets all specific requirements outlined for high-risk AI systems.
# - Implement risk management systems, ensuring thorough assessment and mitigation of risks associated with the AI system.
# - Maintain data governance, ensuring high-quality data handling, integrity, and accuracy.
# - Ensure human oversight and establish processes to allow human intervention in case of system malfunctions or unintended behaviors.
# - Conduct regular testing and validation to ensure the AI system performs as intended and remains compliant with safety and accuracy standards.
#
# **Approach:**
# - The AI system will be classified as high-risk due to its impact on public safety and essential infrastructure management.
# - A comprehensive risk management framework will be developed, including risk assessments and mitigation strategies throughout the project lifecycle.
# - Data governance protocols will be implemented to ensure data quality, security, and integrity, with regular audits and checks.
# - Human oversight mechanisms will be established, including protocols for manual intervention and decision-making.
# - Regular testing and validation of the AI system will be conducted, with performance metrics tracked and reported.
#
# #### Title IV: Transparency Obligations for Providers (Article 52)
# **Obligations:**
# - Inform users that they are interacting with an AI system and provide clear information about its capabilities and limitations.
# - Ensure transparency in AI-generated content, making it clear when content is created or influenced by AI.
#
# **Approach:**
# - The interactive dashboard will include clear notices that predictions and analyses are AI-generated.
# - Documentation and user guides will be provided to explain the AI system's capabilities, limitations, and how to interpret its predictions.
# - Any content or insights generated by the AI will be transparently labeled as AI-generated.
#
# #### Title VIII: Post-Market Monitoring (Article 61; Article 62)
# **Obligations:**
# - Implement post-market monitoring procedures to ensure ongoing compliance, safety, and reliability of the AI system.
# - Regularly update the system to maintain accuracy and prevent bias.
# - Establish processes for reporting and addressing issues or malfunctions that arise post-deployment.
#
# **Approach:**
# - A post-market monitoring plan will be developed, including continuous performance tracking, compliance audits, and user feedback mechanisms.
# - The AI system will undergo regular updates and recalibration to maintain accuracy and address any biases.
# - A reporting mechanism will be established for users to report issues, with a dedicated team in place to address and resolve any problems.
#
# By adhering to these legal obligations, the SmartAccidentPredict project aims to ensure that the AI system is developed and deployed ethically, transparently, and safely. Our approach includes comprehensive risk management, data governance, transparency, human oversight, and continuous monitoring to meet the requirements of the EU AI Act and maintain public trust in the system.
#
# To fulfill these responsibilities, comprehensive documentation of the AI system's development, data origins, and decision-making methods must be kept. Users should undergo training to grasp the AI system's capabilities and limitations. Furthermore, ongoing monitoring is essential to continuously update and evaluate the system for accuracy, bias, and potential harm.

# %% [markdown]
# ### Task 3.3 -  Reflection (Individual Task 3)
#
# For the group assignment you are required to contribute to the group legal assessment of the project. Provide evidences of your contribution and reflection on the legality of the individual contributions made to the project.
#
# This evidence is related to **sufficient** criterion.

# %%
# Include your reflection here and upload evidence of your individual contribution to GitHub. 
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-personal-ViktoriaKubisova231781/blob/16dfdc7439cea5b6de40a46b20e4d810c00d6b19/Datalabs/Week%204/Individual_Risk_Assessment_Legal_Obligations.pdf
# Make sure to link your evidence in your learning log.

# %% [markdown]
# **My reflection**
#
# For the SmartAccidentPredict project, my contributions to the legal assessment included thorough research, documentation, and implementation planning in compliance with the EU AI Act. My primary goal was to ensure that the project adhered to essential legal frameworks, with a specific emphasis on transparency and classification of high-risk factors. This approach guarantees that the project meets both legal mandates and ethical guidelines, promoting the responsible deployment of AI technology used within our dashboard. Below are the evidences of my contributions and reflections on the legality of individual contributions made to the project:
#
# *Research and Documentation*
# - I reviewed the relevant titles and articles of the EU AI Act, specifically focusing on Titles II, III, IV, and VIII.
# - I summarized the legal obligations for our team, highlighting the necessary compliance measures for each relevant article.
# - I documented the steps required to ensure our AI system adheres to the prohibited practices, high-risk classifications and requirements, transparency obligations, and post-market monitoring.
#
# Reflection: Understanding the AI Act's requirements was crucial for guiding the project's direction and ensuring compliance. This research provided a foundation for our team to integrate legal considerations into our technical and operational plans from the outset. Each of the members contributed to the legal assessment in a similar way individually.
#
# **Reflection on the Legality of Individual Contributions**
#
# Each team member's contributions were assessed to ensure they aligned with the legal requirements of the EU AI Act. Below are reflections on the legality of these contributions:
#
# *Data Collection and Pre-processing (Kees, Michal, and Viktoria)*
# - Legal Assessment: Ensured data privacy and integrity during the collection and pre-processing stages. Complied with data governance standards to maintain high data quality.
# - Reflection: Proper data handling is critical for the accuracy and legality of the AI model. This stage laid the groundwork for compliant data use throughout the project.
#
# *Model Development and Training (Kees, Michal, and Viktoria)*
# - Legal Assessment: Implemented risk management strategies during model development to mitigate potential biases and ensure ethical use of AI.
# - Reflection: Developing the model with legal and ethical considerations in mind ensured that the AI system was both effective and compliant with high-risk AI system requirements.
#
# *Interactive Dashboard Development (Jedrzej)*
# - Legal Assessment: Ensured the dashboard was transparent about its AI functionalities and provided users with clear information on AI-generated content.
# - Reflection: Transparency in the user interface is crucial for user trust and legal compliance, particularly under the transparency obligations of the AI Act.
#
# **Summary**
# My contributions to the legal assessment focused on ensuring comprehensive compliance with the EU AI Act through detailed research, planning, and implementation. Each team member's work was assessed for legality, ensuring that our project not only met technical goals but also adhered to legal and ethical standards. This holistic approach was critical in developing a responsible and compliant AI system for the SmartAccidentPredict project.

# %% [markdown]
# ### Task 3.4 - Legal assessment (Group Task 1)
#
# For the group assignment, the team is expected to identify and explain the level of risk associated with the developed AI system.
#
# This evidence is related to **insufficient** criterion.

# %% [markdown]
# As a team, we collectively agree that the SmartAccidentPredict AI system falls within the high-risk category as defined by the EU AI Act. Here is our comprehensive assessment of the risk level associated with our developed AI system:
#
# High-Risk Classification:
# - Purpose and Context:
#     - SmartAccidentPredict is designed to predict the severity of traffic accidents in Breda based on various data inputs such as driver characteristics, weather conditions, and road details. This predictive model plays a crucial role in enhancing road safety and improving emergency response efficiency.
#
# - Potential Impact:
#
#     - Safety-Critical Application: The AI system’s predictions directly influence the deployment of emergency services and law enforcement, impacting public safety outcomes.
#     - Community and Environmental Safety: Accurate predictions can potentially reduce accident severity, lowering the incidence of injuries, fatalities, and property damage.
# - Legal and Ethical Considerations:
#
#     - Compliance Requirements: The EU AI Act imposes stringent obligations on high-risk AI systems, including transparency, data quality assurance, and ongoing post-market monitoring.
#     - Ethical Implications: Responsible AI use entails ensuring fairness, accountability, and transparency in decision-making processes.
# - Mitigation Strategies:
#
#     - Risk Management: We have implemented robust strategies such as comprehensive data governance, bias mitigation in algorithms, and continuous monitoring post-deployment.
#     - User Awareness: Transparent communication regarding the AI system’s capabilities and limitations is essential to foster user trust and comprehension.
#
#
# Conclusion:
# Our team consensus is that the SmartAccidentPredict AI system, due to its role in predicting accident severity and influencing emergency responses, is classified as a high-risk application under the EU AI Act. We are committed to adhering strictly to legal requirements and ethical guidelines to mitigate risks and ensure the safe and responsible deployment of this technology.

# %%
# Make sure to include it to your final presentation.
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/2c11e2ec6e8a9bdac9d0a2a15c17eeb3100b64aa/team15project/Final_Presentation_Team_15.pdf

# %% [markdown]
# ### Task 3.5 - Legal requirements and obligations (Group Task 2)
#
# Identify and mention the legal requirements and obligations vital for addressing in the development of an AI system. Also, identify and mention the legal requirements and obligations that are not necessary to address in the development of an AI system. The legal assessment should be conducted in accordance with the AI Act.
#
# This evidence is related to **sufficient** criterion.

# %% [markdown]
# ### Vital Legal Requirements:
#
# **Prohibited AI Practices (Title II, Article 5):**
#
# - Requirement: Avoidance of prohibited AI practices such as social scoring and biometric identification without consent.
# - Compliance Strategy: Ensuring that the SmartAccidentPredict AI system does not engage in any practices outlined as prohibited under the EU AI Act.
#
# **High-Risk Classification (Title III, Articles 6-15):**
#
# - Requirement: Classification of the SmartAccidentPredict AI system as high-risk due to its impact on public safety and emergency response.
# - Compliance Strategy: Adherence to rigorous requirements for transparency, accountability, and data quality assurance.
#
# **Transparency Obligations (Title IV, Article 52):**
#
# - Requirement: Clear communication of AI system capabilities and limitations to stakeholders and end-users.
# - Compliance Strategy: Development of user-friendly interfaces and documentation to enhance transparency.
#
# **Post-Market Monitoring (Title VIII, Articles 61-62):**
#
# - Requirement: Continuous monitoring of the AI system's performance and impact post-deployment.
# - Compliance Strategy: Implementation of mechanisms for ongoing evaluation and adjustment based on feedback and performance metrics.
#
# Our approach to the legal assessment under the EU AI Act ensures that all relevant requirements are thoroughly addressed in the development of the SmartAccidentPredict AI system. By focusing on vital obligations such as high-risk classification, transparency, prohibition of certain AI practices, and post-market monitoring, we uphold legal compliance and ethical standards while deploying AI to enhance public safety in Breda.

# %%
# Make sure to include the list of legal requirements and obligations that are vital to address for the development of 
# your AI system to your final presentation.
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/2c11e2ec6e8a9bdac9d0a2a15c17eeb3100b64aa/team15project/Final_Presentation_Team_15.pdf
# In case you are developing an AI system that has no or minimum risks, make sure to mention it.

# %% [markdown]
# ### Task 3.6 - Relevance of legal requirements and obligations (Group Task 3)
#
# The group must explain the relevance of legal requirements and obligations included in the group assessment of the project. Ensure to provide reasoning and arguments for both including and excluding specific legal requirements and obligations in the assessment. The reasoning should be supported by facts, details, and examples drawn from multiple sources to substantiate your claims.
#
# If you are developing an AI system that has no or minimal risks, you need to explain the exclusion of each legal requirement and obligation one by one. Provide an explanation and reasoning for why each factor is not applicable to your AI system.
#
# This evidence is related to **good** criterion.

# %% [markdown]
# ### Relevance of Included Legal Requirements and Obligations
#
# **High-Risk Classification (Title III, Articles 6-15):**
#
# - Relevance: The SmartAccidentPredict AI system is classified as high-risk due to its direct impact on public safety and emergency response in Breda. Predicting accident severity and identifying high-risk intersections involves significant implications for public health and safety.
# - Reasoning: High-risk classification under the EU AI Act necessitates adherence to stringent requirements for transparency, accountability, and data quality assurance. This ensures that the AI system's predictions are reliable and actionable for stakeholders such as law enforcement and emergency services.
#
# **Transparency Obligations (Title IV, Article 52):**
#
# - Relevance: Clear communication of the AI system's capabilities, limitations, and potential impacts is crucial for building trust among stakeholders and ensuring responsible use.
# - Reasoning: Transparency helps mitigate concerns about how AI-driven predictions influence decision-making processes related to accident response and road safety infrastructure improvements. Stakeholders need to understand the basis of predictions to effectively integrate them into operational workflows.
#
# **Prohibited AI Practices (Title II, Article 5):**
#
# - Relevance: Although primarily focused on preventing harmful practices like social scoring and unauthorized biometric identification, understanding and complying with prohibited AI practices reinforces ethical standards and prevents misuse of AI technology.
# - Reasoning: While the SmartAccidentPredict AI system does not engage in these specific practices, acknowledging and avoiding prohibited behaviors ensures alignment with broader ethical guidelines and societal expectations regarding AI deployment.
#
# **Post-Market Monitoring (Title VIII, Articles 61-62):**
#
# - Relevance: Continuous monitoring of the AI system post-deployment ensures ongoing compliance with legal requirements and effectiveness in addressing emerging risks or issues.
# - Reasoning: Monitoring allows for timely adjustments based on performance metrics and stakeholder feedback, enhancing the system's reliability and responsiveness to changing conditions in Breda's traffic environment.
#
#
# **Conclusion**
# The inclusion of specific legal requirements and obligations in our group's assessment of the SmartAccidentPredict project is justified by their direct relevance to the system's high-risk classification and societal impact. Each requirement, from high-risk classification to post-market monitoring, contributes to ensuring legal compliance, ethical standards, and the system's effectiveness in enhancing road safety in Breda. By adhering to these obligations, we uphold transparency, accountability, and responsible AI use, thereby fostering trust among stakeholders and maximizing the system's positive impact on public safety.

# %% [markdown]
# ### Task 3.7 - Addressing legal obligations (Group Task 3)
#
# The group provides evidence and explanations of their AI system's compliance with legal requirements and obligations.
#
# If you are developing an AI system with no or minimal risks, ensure to write a paragraph explaining how your AI system complies with EU regulations (AI Act).
#
# This evidence is related to **excellent** criterion.

# %% [markdown]
# ### Compliance with Legal Requirements and Obligations
# Our AI system, SmartAccidentPredict, is classified as high-risk under the EU AI Act due to its significant implications for public safety and emergency response in Breda. As such, we have meticulously ensured compliance with relevant legal requirements and obligations outlined in the EU AI Act to uphold ethical standards and legal integrity.
#
# **High-Risk Classification (Title III, Articles 6-15):**
#
# - SmartAccidentPredict has been classified as high-risk because it predicts accident severity and identifies high-risk intersections, directly impacting public safety. To comply, we have implemented robust measures for transparency, accountability, and data quality assurance throughout the development and deployment phases.
#
# **Transparency Obligations (Title IV, Article 52):**
#
# - Transparency is integral to our AI system's design and deployment. We provide clear documentation and user interfaces that explain the AI's capabilities, limitations, and the basis for predictions. This transparency fosters trust among stakeholders, enabling informed decision-making by law enforcement, emergency services, and city officials.
#
# **Prohibited AI Practices (Title II, Article 5):**
#
# - While SmartAccidentPredict does not engage in prohibited AI practices such as social scoring or unauthorized biometric identification, we acknowledge and adhere to these regulations to ensure ethical use and prevent misuse of AI technology. This commitment aligns with broader societal expectations and ethical guidelines.
#
# **Post-Market Monitoring (Title VIII, Articles 61-62):**
#
# - Continuous monitoring of SmartAccidentPredict post-deployment allows us to evaluate its performance, address any emerging issues, and adapt to evolving regulatory requirements. This proactive approach ensures ongoing compliance and enhances the system's effectiveness in improving road safety.

# %% [markdown]
# ## ILO 4.0: Business Understanding
#
# The student is capable to develop a project proposal  and deliver an impactful presentation to communicate the business values, objectives, and outcomes.
#
# Demonstrate the ability to develop a compelling project proposal  and deliver an impactful presentation that effectively communicates the business value, objectives, and outcomes of the proposed project:
#
# - **Poor**: Clear individual contribution is documented. A project proposal, compliant with professional standards, is prepared and presented.
#
# - **Insufficient**: A final presentation, compliant with professional standards, is prepared and presented. And meeting all criteria in poor.
#
# - **Sufficient**: The students demonstrate a profound understanding of business needs and industry context by developing a project proposal that effectively identifies and addresses client requirements. The proposal includes a clear problem statement, define project objectives, and propose feasible solutions that demonstrate a good understanding of the business environment. And meeting all criteria in insufficient.
#
# - **Good**: The students showcase a strong understanding of the business context in the final project presentation, effectively communicating insights. The final presentation is  engaging, well-structured, and emphasizes the practical implications within the broader business context. And meeting all criteria in sufficient.
#
# - **Excellent**: The students have developed an innovative solution that not only aligns closely with the client's specific requirements but also possesses considerable business value. And meeting all criteria in good.

# %% [markdown]
# ### Task 4.1 - Proposal
#
# Please provide the related link to your team proposal in the following cell. This evidence is related to **poor** and **sufficient** criteria.

# %%
# Put the link to your team proposal here

# Original Proposal
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/b7facfaadae335d0362dae5ed009ccca8181e5fe/team15project/Team_15_Initial_Proposal_Documentpdf.pdf

# Final Proposal
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/b7facfaadae335d0362dae5ed009ccca8181e5fe/team15project/Block%20D%20-%20Project%20Proposal.pdf

# %%
# Put the link to the proposal presentation file here

# Initial and final proposal presentation combined
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/b7facfaadae335d0362dae5ed009ccca8181e5fe/team15project/Final_Proposal_Presentation_Team_15.pdf

# %% [markdown]
# ### Task 4.2 - Final Presentation
#
# Please provide the related link to your final presentation in the following cell. This evidence pertains to **insufficient**, **good**, and **excellent** criteria.If possible, please save your presentation file as a PDF and provide the corresponding link here.

# %%
# Put the link to the final presentation here
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/b7facfaadae335d0362dae5ed009ccca8181e5fe/team15project/Final_Presentation_Team_15.pdf

# %% [markdown]
# ## ILO 5.0: Data Understanding and Preparation
#
# The student is able to collect, combine, explore, and preprocess  data, while assessing data quality, and providing recommendations to improve the data management strategy.
#
# Shows understanding of the data and is able to preprocess a dataset which is suited for further modelling:
#
# - **Poor**: Clear individual contribution is documented. Demonstrates the ability to connect to a SQL database.
#
# - **Insufficient**: Demonstrates the ability to access data in a SQL database using a simple query and meeting all requirements in Poor.
#
# - **Sufficient**: Demonstrates the ability to access data stored in a SQL database from a scripting language such as Python, removes unnecessary columns, handles missing values, addresses any inconsistencies, errors, or outliers, standardizes formats, and encodes categorical variables appropriately, splits the dataset into training, validation, and test sets appropriately and meeting all criteria in insufficient.
#
# - **Good**: Demonstrates the ability to combine data stored in a SQL database using techniques such as a Join, normalize and standardize numerical features, extracts relevant features, or creates new features from date and time information (if applicable), creates new features from existing features to generate more informative ones (if applicable), and meeting all criteria in sufficient.
#
# - **Excellent**: Demonstrates advanced data modelling techniques by expanding out the data warehouse using techniques such as views, balance data considering techniques such as oversampling or undersampling to balance the class distribution (if applicable), normalizes the target variable if it has a skewed distribution, and saves the preprocessing steps and configuration used to be applied consistently to new data and meeting all criteria in good.

# %% [markdown]
# ### Task 5.1 - Connecting to SQL database
#
# Please provide the necessary code to connect to SQL database in the following cell. This requirement relates to **poor** criterion.
#
# __Important!__ Do __NOT__ include usernames or passwords in plain text in your submission.
# You can replace them with Environment Variables, Placeholders, etc.

# %%
# Importing necessary modules
import psycopg2
import pandas as pd
import missingno as msno
import pandas as pd
import phik
from phik import resources
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
# Defining database parameters
db_params = {
    'host': '194.171.191.226',
    'port': '6379',
    'database': 'postgres',
    'user': 'group15',
    'password': 'blockd_2024group15_73'
}

# %%
# Establishing the connection
conn_psycopg2 = psycopg2.connect(**db_params)
cursor = conn_psycopg2.cursor()

# %% [markdown]
# ### Task 5.2 - Accessing Data in Database
#
# Please provide the corresponding code for a simple query to access the data. This requirement is related to the **insufficient** criterion.
#
# __Important!__ Do __NOT__ include usernames or passwords in plain text in your submission.
# You can replace them with Environment Variables, Placeholders, etc.

# %% [markdown]
# To demonstrate our knowledge of using simple SQL queries to access data in our data warehouse, we chose to display the entire table that will be cleaned, preprocessed, and used for our model.
#
# The code below executes an SQL query to select all records from the table *accident_data_17_23* in the **group15_warehouse** database. It uses a cursor object to execute the query and then fetches all the resulting rows. The column names of the table are retrieved from the cursor description. These rows and column names are then used to create a pandas DataFrame, new_accidents, which is subsequently displayed. This process effectively imports the entire dataset from the specified database table into a DataFrame for further analysis or visualization.

# %%
# Execute SQL query to select the whole dataset
query = '''
    SELECT * 
    FROM group15_warehouse.accident_data_17_23;
'''

cursor.execute(query)

# Fetch all rows
new_accident_rows = cursor.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Convert the fetched data into a pandas DataFrame
new_accidents = pd.DataFrame(new_accident_rows, columns=column_names)

# Display the dataset
display(new_accidents)
# Out:
#       Year Accident severity municipality         town  \
# 0     2017             Fatal        Breda        BREDA
# 1     2017             Fatal        Breda        BREDA
# 2     2017             Fatal        Breda        BREDA
# 3     2017           Injured        Breda        BAVEL
# 4     2017           Injured        Breda        BAVEL
# ...    ...               ...          ...          ...
# 6897  2023             Fatal        Breda        BREDA
# 6898  2023             Fatal        Breda        BREDA
# 6899  2023             Fatal        Breda        BREDA
# 6900  2023             Fatal        Breda  PRINSENBEEK
# 6901  2023             Fatal        Breda    ULVENHOUT
#
#      First Mode of Transport Second mode of Transport   Area Type  \
# 0                        Car               Pedestrian  Urban area
# 1                      Lorry                    Other  Urban area
# 2                      Lorry                    Other  Urban area
# ...

# %% [markdown]
# To showcase our ability to also manipulate data with SQL queries, not only selecting the whole dataset, we decided to provide an example of the following query.
#
# This code demonstrates how to use a SQL query to select distinct values from the **Accident Severity** column in the *accident_data_17_23* table within the group15_warehouse database. By executing the query with the cursor, it fetches all unique categories of accident severity. The results are then printed out, displaying each distinct category, thereby illustrating our proficiency in retrieving and working with specific subsets of data from our database.

# %%
# SQL query for selecting distinct categories of Accident Severity
query = '''
    SELECT DISTINCT "Accident severity"
    FROM group15_warehouse.accident_data_17_23;
    '''

cursor.execute(query)

# Fetch all rows
categories = cursor.fetchall()

print("Distinct categories of Accident Severity:")
for category in categories:
    print(category[0])
# Out:
# Distinct categories of Accident Severity:
# Material Damage Only
# Injured
# Fatal

# %% [markdown]
# Our team's ability to connect to the database, access the data, and manipulate it using simple and complex SQL queries is demonstrated in the files linked below:

# %%
# Michal: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/tree/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Michal


# Viktoria: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/tree/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Viktoria


# Jedrek: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/tree/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Jedrek


# Kees: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/tree/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Kees

# %% [markdown]
# ### Task 5.3 - Pre-processing the Data
#
# Please provide the relevant code to perform preprocessing on the data. Refer to the related criterion for detailed instructions on the preprocessing steps. This criterion is associated with the **sufficient** criterion.
#
# __Important!__ Do __NOT__ include usernames or passwords in plain text in your submission.
# You can replace them with Environment Variables, Placeholders, etc.

# %% [markdown]
# #### Distribution analysis

# %% [markdown]
# Before we start preprocessing the data, it is crucial to examine its quality and distribution. Our business goal is to develop a model that predicts accident severity. For this task, we will use the dataset "Accidents_17_23" because it contains valuable and comprehensive information of various types. Therefore, this template will showcase all data cleaning, preprocessing, exploratory data analysis (EDA), and modeling using this dataset. Additionally, we will provide links to our other Jupyter Notebooks at the end of this section. These notebooks will demonstrate the individual contributions of each team member to data preprocessing and analysis.

# %%
# Visualize missing values using missingno
msno.bar(new_accidents)
# Out:
# <Axes: >

# %% [markdown]
# From the graph above, it appears that there are no missing values in this dataset, as every column contains the same number of records—specifically, 6902. Let's explore the data further.

# %%
# Print details of the dataset
print("Data Types:")
print(new_accidents.info())
# Out:
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6902 entries, 0 to 6901
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      6902 non-null   int64
#  1   Accident severity         6902 non-null   object
#  2   municipality              6902 non-null   object
#  3   town                      6902 non-null   object
#  4   First Mode of Transport   6902 non-null   object
#  5   Second mode of Transport  6902 non-null   object
#  6   Area Type                 6902 non-null   object
#  7   Light condition           6902 non-null   object
#  8   Road Location             6902 non-null   object
#  9   Road condition            6902 non-null   object
#  10  Road surface              6902 non-null   object
#  11  Road situation            6902 non-null   object
#  12  Speed limit               6902 non-null   object
# ...

# %% [markdown]
# The dataset contains 6,902 entries and 16 columns. The columns include `Year` and `accidents`, both of which are of integer type (`int64`). The remaining 14 columns are of object type (`object`), indicating they contain categorical data. These columns are `Accident severity`, `municipality`, `town`, `First Mode of Transport`, `Second mode of Transport`, `Area Type`, `Light condition`, `Road Location`, `Road condition`, `Road surface`, `Road situation`, `Speed limit`, `street`, and `weather`. The consistent number of non-null entries across all columns confirms there are no missing values in the dataset. Let's now check the value counts for each column.

# %%
# Get value counts for each column
value_counts_per_column = {col: new_accidents[col].value_counts() for col in new_accidents.columns}

# Display the value counts for each column
for column, counts in value_counts_per_column.items():
    print(f"Value counts for column '{column}':")
    print(counts)
    print()
# Out:
# Value counts for column 'Year':
# Year
# 2017    1274
# 2018    1224
# 2019    1181
# 2022    1146
# 2021    1084
# 2020     985
# 2023       8
# Name: count, dtype: int64
#
# Value counts for column 'Accident severity':
# Accident severity
# Material Damage Only    5916
# Injured                  936
# Fatal                     50
# Name: count, dtype: int64
#
# Value counts for column 'municipality':
# municipality
# Breda    6902
# Name: count, dtype: int64
#
# Value counts for column 'town':
# town
# BREDA          5935
# PRINSENBEEK     416
# BAVEL           296
# TETERINGEN      139
# ULVENHOUT       113
# GALDER            2
# ETTEN-LEUR        1
# Name: count, dtype: int64
#
# Value counts for column 'First Mode of Transport':
# First Mode of Transport
# Car              4350
# -                 853
# Delivery van      496
# Moped             362
# Lorry             240
# Bicycle           181
# Light-moped       166
# Motorcycle        106
# Other              83
# ...

# %% [markdown]
# The value counts analysis of the dataset reveals several insights. Many columns contain significant proportions of "Unknown" values, suggesting incomplete or unspecified data entries. There are also textual inconsistencies noted, such as variations in naming conventions for similar categories (e.g., "Other" and "Other vehicle"). Additionally, the presence of "-" for the "First Mode of Transport" indicates possible missing or unspecified data. The distribution of accidents across different severity levels shows a predominance of incidents categorized as "Material Damage Only," aligning with common accident trends. These observations highlight the importance of data cleaning and standardization processes before conducting further analysis or modeling to ensure accuracy and reliability in predictive models for accident severity. Let's now analyze numerical columns.

# %%
# Specify numeric columns
numeric_columns = ['Year', 'accidents']

# Describe numeric columns
numeric_stats = new_accidents[numeric_columns].describe()
print("Summary statistics for numeric columns:")
print(numeric_stats)
# Out:
# Summary statistics for numeric columns:
#               Year    accidents
# count  6902.000000  6902.000000
# mean   2019.413069     1.390611
# std       1.740494     4.276200
# min    2017.000000     1.000000
# 25%    2018.000000     1.000000
# 50%    2019.000000     1.000000
# 75%    2021.000000     1.000000
# max    2023.000000   151.000000

# %% [markdown]
# The summary statistics for the numeric columns indicate that the dataset spans from 2017 to 2023, with a mean of approximately 1.39 accidents per entry and a standard deviation of 4.28. The median (50th percentile) and the majority of entries (25th to 75th percentile) report 1 accident, with the maximum count of accidents in a single entry reaching 151. These statistics suggest that while most entries record low numbers of accidents, there are outliers with significantly higher counts, which should be further investigated to understand their impact on the dataset's overall distribution and modeling considerations. Now, let's visualize the distribution using a histogram.

# %%
import matplotlib.pyplot as plt

# Plot histograms for numeric columns
new_accidents[numeric_columns].hist(figsize=(10, 8))
plt.suptitle('Histograms of Numeric Columns')
plt.show()

# %% [markdown]
# We have examined the distribution of numerical columns; now it's time to do the same with categorical columns. We will display bar charts to analyze the data distribution.

# %%
# Specify categorical columns
import matplotlib.pyplot as plt

categorical_columns = ['Accident severity', 'municipality', 'town', 
                       'First Mode of Transport', 'Second mode of Transport', 
                       'Area Type', 'Light condition', 'Road Location', 
                       'Road condition', 'Road surface', 'Road situation', 
                       'Speed limit', 'street', 'weather']

# Plot bar charts for categorical columns
fig, axes = plt.subplots(len(categorical_columns), 1, figsize=(10, 6 * len(categorical_columns)))

for i, col in enumerate(categorical_columns):
    new_accidents[col].value_counts().plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'Bar plot of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# The bar charts revealed that for variables with "Unknown" as a value, these entries often account for more than one-third of all records, sometimes even half of the entire dataset. This indicates significant gaps or undefined information in these categories. Additionally, the charts highlighted additional textual inconsistencies within the dataset, suggesting variations or errors in how certain data entries are recorded or categorized. Addressing these issues through thorough data cleaning and standardization processes will be crucial to ensure the reliability and accuracy of any further analysis or modeling efforts based on this dataset. Now that we have completed some initial data distribution analysis, we can proceed to preprocessing.

# %%
# Suppress warnings
warnings.filterwarnings('ignore', category=UserWarning)

# Calculate the correlation matrix using phik
phik_matrix = new_accidents.phik_matrix(interval_cols=[])

# Create the heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(phik_matrix.values, annot=True, fmt='.2f', cmap='coolwarm', center=0,
            xticklabels=phik_matrix.columns, yticklabels=phik_matrix.index)
plt.title('Correlation Heatmap of All Variables (Phik)')
plt.show()

# %% [markdown]
# #### Basic preprocessing

# %% [markdown]
# Let's start with preprocessing. We'll begin by addressing some textual inconsistencies in variable naming. All column names will be converted to capitalized format to maintain consistency and ease of reference. Standardizing column names helps ensure clarity and uniformity across the dataset, making data manipulation and analysis easier.

# %%
# Convert all column names to capitalized format
new_accidents = new_accidents.rename(columns=lambda x: x.capitalize())

# Display the updated DataFrame
print("DataFrame with capitalized column names:")
display(new_accidents)
# Out:
# DataFrame with capitalized column names:
#       Year Accident severity Municipality         Town  \
# 0     2017             Fatal        Breda        BREDA
# 1     2017             Fatal        Breda        BREDA
# 2     2017             Fatal        Breda        BREDA
# 3     2017           Injured        Breda        BAVEL
# 4     2017           Injured        Breda        BAVEL
# ...    ...               ...          ...          ...
# 6897  2023             Fatal        Breda        BREDA
# 6898  2023             Fatal        Breda        BREDA
# 6899  2023             Fatal        Breda        BREDA
# 6900  2023             Fatal        Breda  PRINSENBEEK
# 6901  2023             Fatal        Breda    ULVENHOUT
#
#      First mode of transport Second mode of transport   Area type  \
# 0                        Car               Pedestrian  Urban area
# 1                      Lorry                    Other  Urban area
# ...

# %% [markdown]
# After renaming the columns, we will proceed with handling missing values. This code snippet checks for missing values in the new_accidents DataFrame and prints out the count of missing values for each column.

# %%
# Handling missing values
missing_values = new_accidents.isnull().sum()
print("Missing values:")
print(missing_values)
# Out:
# Missing values:
# Year                        0
# Accident severity           0
# Municipality                0
# Town                        0
# First mode of transport     0
# Second mode of transport    0
# Area type                   0
# Light condition             0
# Road location               0
# Road condition              0
# Road surface                0
# Road situation              0
# Speed limit                 0
# Street                      0
# Weather                     0
# Accidents                   0
# dtype: int64

# %% [markdown]
# The data exploration above confirmed that the dataset does not contain explicitly missing values throughout its entirety. Therefore, no imputation or deletion of missing values was necessary, ensuring the dataset's completeness and alignment with our project's objectives. However, if we recall back to eh value count in the previous section, numerous entries were labeled as 'Unknown', indicating situations where sensor and camera data could not definitively determine categorical values. These 'Unknown' entries were retained to accurately reflect real-world conditions captured by our data collection methods.
#
# Let's now move on to removing duplicates from the dataset if there are any, which will prevent redundancy and ensure that each accident instance is represented only once in the dataset, avoiding skewed results and preventing overfitting during model training.

# %%
# Removing duplicates
new_accidents.drop_duplicates(inplace=True)

# %% [markdown]
# Having successfully addressed duplicates, we will now move on to feature selection. Referring back to the value count in the section above, we observed that the 'Municipality' column contained uniform data ('Breda'), which does not contribute to predicting accident severity. Therefore, we will remove the 'Municipality' column to streamline the dataset.

# %%
# Dropping unnecessary columns
new_accidents = new_accidents.drop(columns=['Municipality'])

# %% [markdown]
# After dropping the 'Municipality' column, we can address a few more textual inconsistencies. Specifically, in the 'First Mode of Transport' and 'Second Mode of Transport' columns, we will replace values 'Other vehicle' and '-' with 'Other'. These values likely represent some other category of a vehicle or object. This transformation consolidates similar categories ('Other vehicle' and '-') into a single category ('Other'), simplifying the categorical variables and potentially enhancing model performance.

# %%
# Make changes in variable values
# Replace 'Other vehicle' and '-' with 'Other' in 'First Mode of Transport'
new_accidents['First mode of transport'] = new_accidents['First mode of transport'].replace({'Other vehicle': 'Other', '-': 'Other'})

# Replace 'Other vehicle' with 'Other' in 'Second mode of Transport'
new_accidents['Second mode of transport'] = new_accidents['Second mode of transport'].replace({'Other vehicle': 'Other'})

# %% [markdown]
# Next, we will address another textual inconsistency by standardizing the names in the 'Town' column. Currently written in all capital letters, we will capitalize the town names uniformly. This adjustment minimizes data entry errors and ensures consistency in town names across the dataset.

# %%
# Handling textual data inconsistencies
new_accidents['Town'] = new_accidents['Town'].str.capitalize()

# %% [markdown]
# Now, after addressing data inconsistencies, we will perform data type conversion. From the information printed about the data, we observed that all our categorical columns were of type 'object', which is not optimal for modeling. Therefore, categorical variables will be converted to the 'category' data type. This conversion optimizes memory usage and enhances computational efficiency during modeling and analysis.

# %%
# Converting categorical variables to category type
categorical_cols = ['Accident severity', 'Town', 'First mode of transport', 'Second mode of transport',
                    'Area type', 'Light condition', 'Road location', 'Road condition', 'Road surface', 'Road situation', 'Speed limit', 'Street', 'Weather']

for col in categorical_cols:
    new_accidents[col] = new_accidents[col].astype('category')

# %% [markdown]
# After completing these basic preprocessing steps, it's time to address outliers based on the number of accidents. Let's begin by visualizing them.

# %%
# Visualising outliers
import seaborn as sns
sns.boxplot(x=new_accidents['Accidents'])
plt.show()

# %% [markdown]
# As we can see, most of our data is clustered in the range of 1 to 20 accidents per record. However, there are a few instances with a higher number of accidents, reaching up to 150. Let's detect these outliers using the Interquartile Range (IQR) method and visualize them to analyze them further.

# %%
import numpy as np

# Define a function to detect outliers using IQR
def detect_outliers(df, columns):
    outliers_indices = []
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outliers_indices.extend(outliers.index)
    return list(set(outliers_indices))

# Specify columns to check for outliers
numeric_columns = ['Accidents'] 

# Detect outliers
outlier_indices = detect_outliers(new_accidents, numeric_columns)

print("Rows corresponding to outliers:")
display(new_accidents.loc[outlier_indices].head(20))

# Display value counts for accidents of the outliers
print("Value counts for accidents of the outliers:")
display(new_accidents.loc[outlier_indices, 'Accidents'].value_counts())
# Out:
# Rows corresponding to outliers:
#       Year     Accident severity   Town First mode of transport  \
# 2050  2018  Material Damage Only  Breda                     Car
# 4099  2020  Material Damage Only  Breda                     Car
# 2053  2018  Material Damage Only  Breda                     Car
# 2061  2018  Material Damage Only  Breda                     Car
# 2075  2018  Material Damage Only  Breda                     Car
# 2076  2018  Material Damage Only  Breda                     Car
# 4128  2020  Material Damage Only  Breda                     Car
# 6177  2022  Material Damage Only  Breda                     Car
# 4130  2020  Material Damage Only  Breda                     Car
# 2084  2018  Material Damage Only  Breda                     Car
# 2089  2018  Material Damage Only  Breda                     Car
# 6186  2022  Material Damage Only  Breda                     Car
# 2093  2018  Material Damage Only  Breda                     Car
# ...

# %% [markdown]
# Since some of the values among these outliers appear to be erroneous entries or data recording mistakes, which fall outside the expected range of real-world data, we have decided to remove them. While some of these cases might represent rare but valid occurrences, our analysis will focus solely on records where the number of accidents is 1. This decision stems from our findings that the variable "Accidents" shows no correlation with accident severity, as indicated by the correlation matrix derived from our data. Therefore, we will remove these outliers from the dataset and subsequently drop the "Accidents" column, as it no longer serves a necessary purpose now that all entries are adjusted to 1.

# %%
# Drop outliers from the DataFrame
new_accidents = new_accidents.drop(outlier_indices)

# Drop the "Accidents" column as it's no longer needed
new_accidents = new_accidents.drop('Accidents', axis=1)

# Display the cleaned DataFrame
print("Cleaned DataFrame after removing outliers and 'Accidents' column:")
display(new_accidents.head())
# Out:
# Cleaned DataFrame after removing outliers and 'Accidents' column:
#    Year Accident severity   Town First mode of transport  \
# 0  2017             Fatal  Breda                     Car
# 1  2017             Fatal  Breda                   Lorry
# 2  2017             Fatal  Breda                   Lorry
# 3  2017           Injured  Bavel                     Car
# 4  2017           Injured  Bavel                     Car
#
#   Second mode of transport   Area type Light condition Road location  \
# 0               Pedestrian  Urban area        Darkness  Intersection
# 1                    Other  Urban area        Daylight  Intersection
# 2                    Other  Urban area        Daylight  Road section
# 3                    Lorry  Rural area        Darkness  Road section
# 4                    Other  Rural area        Darkness  Road section
#
#   Road condition     Road surface         Road situation Speed limit  \
# ...

# %% [markdown]
# Great, we've successfully addressed the outliers and removed the unnecessary column. Now, let's display an overview of the dataset.

# %%
# Print details of the dataset
print("Data Types:")
print(new_accidents.info())
# Out:
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6359 entries, 0 to 6901
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      6359 non-null   int64
#  1   Accident severity         6359 non-null   category
#  2   Town                      6359 non-null   category
#  3   First mode of transport   6359 non-null   category
#  4   Second mode of transport  6359 non-null   category
#  5   Area type                 6359 non-null   category
#  6   Light condition           6359 non-null   category
#  7   Road location             6359 non-null   category
#  8   Road condition            6359 non-null   category
#  9   Road surface              6359 non-null   category
#  10  Road situation            6359 non-null   category
#  11  Speed limit               6359 non-null   category
#  12  Street                    6359 non-null   category
# ...

# %% [markdown]
# #### Advanced preprocessing

# %% [markdown]
# As an advanced preprocessing step to showcase our skills in feature engineering, we have decided to create a new variable called 'Road type'. This variable categorizes the type of road based on the speed limit.

# %%
#  Define the updated mapping dictionary
speed_to_road_type = {
    '130 km/h': 'Highway',
    '120 km/h': 'Highway',
    '100 km/h': 'Rural Road',
    '90 km/h': 'Rural Road',
    '80 km/h': 'Rural Road',
    '70 km/h': 'Build-up Road',
    '50 km/h': 'Urban Road',
    '30 km/h': 'Town Center Road',
    '60 km/h': 'Build-up Road',
    '15 km/h': 'Residential Road',
    'Footpace / homezone': 'Honezone Road',
    'Unknown': 'Unknown'
}

# Create the new column 'Road Type' based on 'Speed limit'
new_accidents['Road type'] = new_accidents['Speed limit'].map(speed_to_road_type)

# Check the distribution of the new column
print(new_accidents['Road type'].value_counts())

# Display the first few rows to verify the changes
display(new_accidents.head())
# Out:
# Road type
# Urban Road          2684
# Town Center Road    1040
# Unknown              997
# Build-up Road        659
# Highway              592
# Rural Road           350
# Residential Road      31
# Honezone Road          6
# Name: count, dtype: int64
#    Year Accident severity   Town First mode of transport  \
# 0  2017             Fatal  Breda                     Car
# 1  2017             Fatal  Breda                   Lorry
# 2  2017             Fatal  Breda                   Lorry
# 3  2017           Injured  Bavel                     Car
# 4  2017           Injured  Bavel                     Car
#
#   Second mode of transport   Area type Light condition Road location  \
# 0               Pedestrian  Urban area        Darkness  Intersection
# 1                    Other  Urban area        Daylight  Intersection
# 2                    Other  Urban area        Daylight  Road section
# 3                    Lorry  Rural area        Darkness  Road section
# ...

# %% [markdown]
# Another advanced preprocessing step involves label encoding the categorical variables. This step is essential for preparing the data so that models can effectively handle categorical information.

# %%
# Label encode categorical variables
from sklearn.preprocessing import LabelEncoder

categorical_cols = ['Accident severity', 'Town', 'First mode of transport', 'Second mode of transport',
                    'Area type', 'Light condition', 'Road location', 'Road condition', 'Road surface', 'Road situation', 'Speed limit', 'Street', 'Weather', 'Road type']

label_encoders = {}
for column in categorical_cols:
    le = LabelEncoder()
    new_accidents[column] = le.fit_transform(new_accidents[column])
    label_encoders[column] = le  # Store the label encoder for inverse transformation if needed

# Check the resulting DataFrame
display(new_accidents.head())
# Out:
#    Year  Accident severity  Town  First mode of transport  \
# 0  2017                  0     1                        2
# 1  2017                  0     1                        5
# 2  2017                  0     1                        5
# 3  2017                  1     0                        2
# 4  2017                  1     0                        2
#
#    Second mode of transport  Area type  Light condition  Road location  \
# 0                         9          2                0              0
# 1                         8          2                1              0
# 2                         8          2                1              1
# 3                         5          0                0              1
# 4                         8          0                0              1
#
#    Road condition  Road surface  Road situation  Speed limit  Street  Weather  \
# 0               3             1               0            4     750        3
# ...

# %% [markdown]
# Our data has been preprocessed to remove missing data, duplicates, outliers, and unnecessary columns, and it has been label encoded. With the data now prepared, we will proceed to separate features and target variable and split it into training and test sets. We have chosen a 70/30 split due to the imbalanced distribution of our target variable, which includes only 50 fatal accident records. This split will help ensure that our model can effectively learn to detect this rare outcome. During the split, we will use stratify=y to maintain the proportion of each class (accident severity) in both the training and test datasets, which is crucial for preserving the distribution of the target variable across the splits."

# %%
# Separate features and target variable
X = new_accidents.drop(columns=['Accident severity']) 
y = new_accidents['Accident severity']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42,
                                                    stratify=y)

# %% [markdown]
# ### Task 5.4 - Advanced Pre-processing of Data
#
# Please provide the relevant code for joining datasets and performing advanced data preprocessing. Refer to the **good** criterion explanation for a better understanding of the steps to consider for this criterion. This evidence corresponds to the **good** criterion.
#
# __Important!__ Do __NOT__ include usernames or passwords in plain text in your submission.
# You can replace them with Environment Variables, Placeholders, etc.

# %% [markdown]
# Our project focuses exclusively on the **Accident_17_23** dataset as it contains all the essential information for predicting accident severity. Due to the absence of matching variables that could serve as keys, we were unable to join this dataset with any other datasets. Therefore, we are unable to demonstrate our skills in joining datasets with this specific dataset used for our model. However, our proficiency in joining datasets using SQL is demonstrated in the following linked files.
#
# Viktoria: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-personal-ViktoriaKubisova231781/blob/842266a8fbcf27e9d80090edcfdfdec89180d2a0/Datalabs/Week%202/231781_Week_II_Tuesday_SQLTasks.ipynb
#
# Kees: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/tree/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Kees
#
# Regarding feature normalization, after basic preprocessing, we removed the 'Accidents' column, leaving only one numerical column in our dataset, which is 'Year'. Normalization is typically applied to numerical data where the scale of values can vary significantly. However, since 'Year' is the sole numerical feature in our dataset and inherently on a meaningful scale, it does not require scaling for most machine learning algorithms. Moreover, with all categorical features label-encoded, scaling or normalization of 'Year' is unnecessary. However, our proficiency in scaling numerical features is demonstrated in the linked file below.
#
# Viktoria: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Viktoria/Viktoria_Preprocessing%20for%20modelling.ipynb
#
#
# In the preceding section, Task 5.3, we demonstrated our proficiency in creating new features such as 'Road Type' based on existing features like "Speed limit". However, the files linked below highlight our ability to aggregate data, extract information, or create new features from dates and time information. During our data processing for unsupervised learning algorithms, we also introduced a new feature called 'Intersection ID,' which aggregates accidents occurring within specific perimeters of road intersections. The evidence can be found in the files linked below.
#
# Kees: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/tree/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Kees

# %% [markdown]
# ### Task 5.5 - Final Data Preparation
#
# Please provide evidence of the techniques used to balance the class distribution and normalize the target variable, if applicable. This corresponds to the first part of the **Excellent** criterion.
#
# __Important!__ Do __NOT__ include usernames or passwords in plain text in your submission.
# You can replace them with Environment Variables, Placeholders, etc.

# %%
# The following file demonstrated our ability to create VIEWS from data using SQL.

# Kees: https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Kees/sql_joins.ipynb

# %% [markdown]
# Let's perform class distribution analysis on our target variable to assess its skewness and plan appropriate actions.

# %%
# Assuming you have already calculated class_distribution
class_distribution = new_accidents['Accident severity'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(8, 6))
bars = class_distribution.plot(kind='bar', color='skyblue')

# Adding labels above bars
for bar in bars.patches:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 30, bar.get_height(), ha='center', va='bottom')

plt.title('Class Distribution of Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# The label '0' corresponds to fatal accidents, '1' to injured, and '2' to material damage only. The class distribution of accident severity shows a significant imbalance, with the majority of accidents categorized as material damage only (5386 records), followed by injured accidents (923 records), and a minority being fatal accidents (50 records). This imbalance poses a challenge for the model to effectively predict fatal accidents. To address this issue, we will employ Synthetic Minority Over-sampling Technique (SMOTE) to synthetically increase the samples of the minority class and balance the class distribution in the feature space. Additionally, we will use class weighting during model training to penalize misclassifications of minority classes more than majority classes. Many classification models provide a hyperparameter called 'class_weight' for this purpose, which we will utilize. Let's now apply SMOTE to our train dataset.

# %%
# Apply SMOTE to balance the classes in the training set
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# %% [markdown]
# Please provide a link to a PDF file in the following cell. This PDF should explain all the preprocessing steps and configurations used to prepare the data before proceeding to the modeling phase of the project. In addition, the PDF should include a schema diagram of your data warehouse this corresponds with the **Excellent** criterion.

# %%
# Put the link to the PDF file here
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/3644f9ca6c5ed328255adfb39d3a6c5cee37fc21/team15project/Data%20Preprocessing%20Steps.pdf

# %% [markdown]
# ## ILO 6.0: Modelling, Evaluation, and Iteration
#
# The student is able to select, implement and evaluate machine learning models, and improve their performance through iteration(s) to meet the business requirement.
#
# Demonstrates basic knowledge of modeling, evaluation, and iteration in developing both traditional and deep machine learning models, as well as understanding of the concept of the trade-off between model complexity and performance:
#
# - **Poor**: Clear individual contribution is documented. The student demonstrates the ability to  select a suitable machine learning algorithm based on the task's nature (e.g., classification, regression, time series prediction) and data characteristics. The student is able to  train a model using the chosen algorithm on the training dataset.
#
# - **Insufficient**: The student demonstrates the ability to evaluate a trained model's performance on a dataset, measuring its ability to generalize to new, unseen data. Additionally, the student exhibits the ability to select suitable evaluation metrics based on the type of task the model is designed for. And meeting all criteria in poor.
#
# - **Sufficient**: The student demonstrates the ability to iteratively refine and enhance the model's performance on a specific problem through a cycle involving training, evaluating results, and making adjustments. These adjustments encompass fine-tuning hyperparameters, modifying the model architecture, and improving data pre-processing steps. And meeting all criteria in insufficient.
#
# - **Good**: The student demonstrates the ability to select the appropriate machine learning algorithm, considering the trade-off between the desired model complexity and the required level of performance for a specific task. The students is able to compare at least two different relevant machine learning models for a specific task based on their final performance and complexity. And meeting all criteria in sufficient.
#
# - **Excellent**: The student demonstrates the capability to develop deep machine learning models, such as conducting time series forecasting using recurrent neural networks, implementing deep neural networks for classification or regression, training autoencoder neural networks for unsupervised learning or feature learning. And meeting all criteria in good.

# %% [markdown]
# ### Task 6.1 - Modelling
#
# Please provide a link to a file in the following cell, which clarifies the individual contributions of all your team members. This is the first part of the evidences for the **poor** criterion.

# %%
# Put the related link here

https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/7fe9f752e3090477ac6f1a61ed6c51cb1406418d/team15project/ILO%206%20individual%20contribution.pdf

# Imports
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV
import scipy.stats as stats

# %% [markdown]
# Please provide the corresponding code for training the model based on your chosen algorithm. This is the second piece of evidence corresponding to the **poor** criterion.

# %% [markdown]
# #### Logistic Regression Model

# %%
# Initialize the model
log_reg_1 = LogisticRegression(max_iter=10000, random_state=42)

# Train the model
log_reg_1.fit(X_train, y_train)

# Make predictions
y_pred_log_reg_1 = log_reg_1.predict(X_test)

# %% [markdown]
# #### Random Forest Model

# %%
# Initialize the model
rf_clf_1 = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_clf_1.fit(X_train, y_train)

# Make predictions
y_pred_rf_1 = rf_clf_1.predict(X_test)

# %% [markdown]
# #### Gradient Boosting Model

# %%
# Initialize the model
gb_clf_1 = GradientBoostingClassifier(n_estimators=100, random_state=42)

# Train the model
gb_clf_1.fit(X_train, y_train)

# Make predictions
y_pred_gb_1 = gb_clf_1.predict(X_test)

# %% [markdown]
# ### Task 6.2 - Evaluation
#
# Please provide the related link for the evaluation of the trained model. This evidence relates to the **insufficient** criterion.

# %% [markdown]
# #### Logistic Regression Model

# %%
# Evaluate the model
print("Logistic Regression Model:")
cr_lr_1 = classification_report(y_test, y_pred_log_reg_1, zero_division=1)
cm_lr_1 = confusion_matrix(y_test, y_pred_log_reg_1)
print(cr_lr_1)
print(cm_lr_1)

# Calculate overall accuracy
accuracy_lr_1 = accuracy_score(y_test, y_pred_log_reg_1)
print(f"Overall Accuracy: {accuracy_lr_1:.2f}")
# Out:
# Logistic Regression Model:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        15
#            1       1.00      0.00      0.00       277
#            2       0.85      1.00      0.92      1616
#
#     accuracy                           0.85      1908
#    macro avg       0.95      0.33      0.31      1908
# weighted avg       0.87      0.85      0.78      1908
#
# [[   0    0   15]
#  [   0    0  277]
#  [   0    0 1616]]
# Overall Accuracy: 0.85

# %% [markdown]
# #### Random Forest Model

# %%
# Evaluate the model
print("Random Forest Classifier Model:")
cr_rf_1 = classification_report(y_test, y_pred_rf_1, zero_division=1)
cm_rf_1 = confusion_matrix(y_test, y_pred_rf_1)
print(cr_rf_1)
print(cm_rf_1)

# Calculate overall accuracy
accuracy_rf_1 = accuracy_score(y_test, y_pred_rf_1)
print(f"Overall Accuracy: {accuracy_rf_1:.2f}")
# Out:
# Random Forest Classifier Model:
#               precision    recall  f1-score   support
#
#            0       1.00      0.13      0.24        15
#            1       0.44      0.12      0.19       277
#            2       0.86      0.97      0.91      1616
#
#     accuracy                           0.84      1908
#    macro avg       0.77      0.41      0.45      1908
# weighted avg       0.80      0.84      0.80      1908
#
# [[   2    0   13]
#  [   0   34  243]
#  [   0   43 1573]]
# Overall Accuracy: 0.84

# %% [markdown]
# #### Gradient Boosting Model

# %%
# Evaluate the model
print("Gradient Boosting Classifier Model:")
cr_gb_1 = classification_report(y_test, y_pred_gb_1, zero_division=1)
cm_gb_1 = confusion_matrix(y_test, y_pred_gb_1)
print(cr_gb_1)
print(cm_gb_1)

# Calculate overall accuracy
accuracy_gb_1 = accuracy_score(y_test, y_pred_gb_1)
print(f"Overall Accuracy: {accuracy_gb_1:.2f}")
# Out:
# Gradient Boosting Classifier Model:
#               precision    recall  f1-score   support
#
#            0       0.60      0.20      0.30        15
#            1       0.52      0.09      0.16       277
#            2       0.86      0.99      0.92      1616
#
#     accuracy                           0.85      1908
#    macro avg       0.66      0.43      0.46      1908
# weighted avg       0.81      0.85      0.80      1908
#
# [[   3    2   10]
#  [   2   26  249]
#  [   0   22 1594]]
# Overall Accuracy: 0.85

# %% [markdown]
# ### Task 6.3 - Iteration
#
# Please provide all the corresponding code for improving the model performance, taking into account the iterations. For more details on the types of iterations required, please refer to the explanation for the sufficient criterion. This evidence corresponds to the **sufficient** criterion.

# %% [markdown]
# #### Logistic Regression Model - Iteration 2: Fixing class imbalance by adding class_weight='balanced'

# %%
# Initialize the model
log_reg_2 = LogisticRegression(max_iter=100000, random_state=42, class_weight='balanced')

# Train the model
log_reg_2.fit(X_train, y_train)

# Make predictions
y_pred_log_reg_2 = log_reg_2.predict(X_test)

# Evaluate the model
print("Logistic Regression Model:")
cr_lr_2 = classification_report(y_test, y_pred_log_reg_2, zero_division=1)
cm_lr_2 = confusion_matrix(y_test, y_pred_log_reg_2)
print(cr_lr_2)
print(cm_lr_2)

# Calculate overall accuracy
accuracy_lr_2 = accuracy_score(y_test, y_pred_log_reg_2)
print(f"Overall Accuracy: {accuracy_lr_2:.2f}")
# Out:
# Logistic Regression Model:
#               precision    recall  f1-score   support
#
#            0       0.02      0.47      0.03        15
#            1       0.20      0.52      0.29       277
#            2       0.92      0.43      0.59      1616
#
#     accuracy                           0.45      1908
#    macro avg       0.38      0.47      0.30      1908
# weighted avg       0.81      0.45      0.54      1908
#
# [[  7   4   4]
#  [ 75 144  58]
#  [347 569 700]]
# Overall Accuracy: 0.45

# %% [markdown]
# #### Random Forest Model - Iteration 2: Fixing class imbalance by adding class_weight='balanced'¶

# %%
# Initialize the model
rf_clf_2 = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')

# Train the model
rf_clf_2.fit(X_train, y_train)

# Make predictions
y_pred_rf_2 = rf_clf_2.predict(X_test)

# Evaluate the model
print("Random Forest Classifier Model:")
cr_rf_2 = classification_report(y_test, y_pred_rf_2, zero_division=1)
cm_rf_2 = confusion_matrix(y_test, y_pred_rf_2)
print(cr_rf_2)
print(cm_rf_2)

# Calculate overall accuracy
accuracy_rf_2 = accuracy_score(y_test, y_pred_rf_2)
print(f"Overall Accuracy: {accuracy_rf_2:.2f}")
# Out:
# Random Forest Classifier Model:
#               precision    recall  f1-score   support
#
#            0       1.00      0.13      0.24        15
#            1       0.26      0.05      0.08       277
#            2       0.85      0.98      0.91      1616
#
#     accuracy                           0.84      1908
#    macro avg       0.70      0.39      0.41      1908
# weighted avg       0.77      0.84      0.78      1908
#
# [[   2    0   13]
#  [   0   13  264]
#  [   0   37 1579]]
# Overall Accuracy: 0.84

# %% [markdown]
# #### Gradeint Boosting Model - Iteration 2: Fixing class imbalance by adding sample_weight

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.utils.class_weight import compute_sample_weight

# Compute sample weights
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)

# Initialize the model
gb_clf_2 = GradientBoostingClassifier(n_estimators=100, random_state=42)

# Train the model
gb_clf_2.fit(X_train, y_train, sample_weight=sample_weights)

# Make predictions
y_pred_gb_2 = gb_clf_2.predict(X_test)

# Evaluate the model
print("Gradient Boosting Classifier Model:")
cr_gb_2 = classification_report(y_test, y_pred_gb_2, zero_division=1)
cm_gb_2 = confusion_matrix(y_test, y_pred_gb_2)
print(cr_gb_2)
print(cm_gb_2)

# Calculate overall accuracy
accuracy_gb_2 = accuracy_score(y_test, y_pred_gb_2)
print(f"Overall Accuracy: {accuracy_gb_2:.2f}")
# Out:
# Gradient Boosting Classifier Model:
#               precision    recall  f1-score   support
#
#            0       0.04      0.27      0.06        15
#            1       0.26      0.60      0.36       277
#            2       0.92      0.66      0.77      1616
#
#     accuracy                           0.65      1908
#    macro avg       0.41      0.51      0.40      1908
# weighted avg       0.82      0.65      0.71      1908
#
# [[   4    7    4]
#  [  28  165   84]
#  [  81  466 1069]]
# Overall Accuracy: 0.65

# %% [markdown]
# #### Logistic Regression Model - Iteration 3: Fixing class imbalance using SMOTE

# %%
# Initialize the Logistic Regression model with SMOTE
log_reg_3 = LogisticRegression(max_iter=10000, random_state=42, class_weight='balanced')

# Train the model
log_reg_3.fit(X_train_res, y_train_res)

# Make predictions
y_pred_log_reg_3 = log_reg_3.predict(X_test)

# Evaluate the model
print("Logistic Regression Model:")
cr_lr_3 = classification_report(y_test, y_pred_log_reg_3, zero_division=1)
cm_lr_3 = confusion_matrix(y_test, y_pred_log_reg_3)
print(cr_lr_3)
print(cm_lr_3)

# Calculate overall accuracy
accuracy_lr_3 = accuracy_score(y_test, y_pred_log_reg_3)
print(f"Overall Accuracy: {accuracy_lr_3:.2f}")
# Out:
# Logistic Regression Model:
#               precision    recall  f1-score   support
#
#            0       0.02      0.33      0.04        15
#            1       0.22      0.41      0.29       277
#            2       0.88      0.64      0.74      1616
#
#     accuracy                           0.60      1908
#    macro avg       0.38      0.46      0.36      1908
# weighted avg       0.78      0.60      0.67      1908
#
# [[   5    5    5]
#  [  34  113  130]
#  [ 189  394 1033]]
# Overall Accuracy: 0.60

# %% [markdown]
# #### Random Forest Model - Iteration 3: Fixing class imbalance using SMOTE

# %%
# Initialize the Random Forest Classifier with SMOTE
rf_clf_3 = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')

# Train the model
rf_clf_3.fit(X_train_res, y_train_res)

# Make predictions
y_pred_rf_3 = rf_clf_3.predict(X_test)

# Evaluate the model
print("Random Forest Classifier Model with SMOTE:")
cr_rf_3 = classification_report(y_test, y_pred_rf_3, zero_division=1)
cm_rf_3 = confusion_matrix(y_test, y_pred_rf_3)
print(cr_rf_3)
print(cm_rf_3)

# Calculate overall accuracy
accuracy_rf_3 = accuracy_score(y_test, y_pred_rf_3)
print(f"Overall Accuracy: {accuracy_rf_3:.2f}")
# Out:
# Random Forest Classifier Model with SMOTE:
#               precision    recall  f1-score   support
#
#            0       0.05      0.07      0.06        15
#            1       0.24      0.26      0.25       277
#            2       0.87      0.85      0.86      1616
#
#     accuracy                           0.76      1908
#    macro avg       0.39      0.39      0.39      1908
# weighted avg       0.77      0.76      0.77      1908
#
# [[   1    4   10]
#  [   4   73  200]
#  [  14  221 1381]]
# Overall Accuracy: 0.76

# %% [markdown]
# #### Gradient Boosting Model - Iteration 3: Fixing class imbalance using SMOTE

# %%
# Initialize the Gradient Boosting Classifier with SMOTE
gb_clf_3 = GradientBoostingClassifier(n_estimators=100, random_state=42)

# Train the model
gb_clf_3.fit(X_train_res, y_train_res)

# Make predictions
y_pred_gb_3 = gb_clf_3.predict(X_test)

# Evaluate the model
print("Gradient Boosting Classifier Model with SMOTE:")
cr_gb_3 = classification_report(y_test, y_pred_gb_3, zero_division=1)
cm_gb_3 = confusion_matrix(y_test, y_pred_gb_3)
print(cr_gb_3)
print(cm_gb_3)

# Calculate overall accuracy
accuracy_gb_3 = accuracy_score(y_test, y_pred_gb_3)
print(f"Overall Accuracy: {accuracy_gb_3:.2f}")
# Out:
# Gradient Boosting Classifier Model with SMOTE:
#               precision    recall  f1-score   support
#
#            0       0.03      0.13      0.05        15
#            1       0.23      0.34      0.28       277
#            2       0.88      0.78      0.83      1616
#
#     accuracy                           0.71      1908
#    macro avg       0.38      0.42      0.38      1908
# weighted avg       0.78      0.71      0.74      1908
#
# [[   2    7    6]
#  [  15   94  168]
#  [  56  300 1260]]
# Overall Accuracy: 0.71

# %% [markdown]
# #### Logistic Regression Model - Iteration 4: Hyper-tuning

# %%
# Define parameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'saga']
}

# Initialize Logistic Regression classifier
log_reg_4 = LogisticRegression(max_iter=10000, random_state=42, class_weight='balanced')

# Instantiate GridSearchCV
grid_search = GridSearchCV(log_reg_4, param_grid, cv=5, scoring='accuracy', verbose=1)

# Fit the grid search
grid_search.fit(X_train_res, y_train_res)

# Print the best parameters and best score
print("Best parameters found for Logistic Regression:")
print(grid_search.best_params_)
print("Best cross-validation accuracy score: {:.2f}".format(grid_search.best_score_))

# Make predictions using the best model
y_pred_log_reg_4 = grid_search.predict(X_test)

# Evaluate the model
print("Logistic Regression Model:")
cr_lr_4 = classification_report(y_test, y_pred_log_reg_4, zero_division=1)
cm_lr_4 = confusion_matrix(y_test, y_pred_log_reg_4)
print(cr_lr_4)
print(cm_lr_4)

# Calculate overall accuracy
accuracy_lr_4 = accuracy_score(y_test, y_pred_log_reg_4)
print(f"Overall Accuracy: {accuracy_lr_4:.2f}")
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best parameters found for Logistic Regression:
# {'C': 10, 'solver': 'liblinear'}
# Best cross-validation accuracy score: 0.64
# Logistic Regression Model:
#               precision    recall  f1-score   support
#
#            0       0.02      0.33      0.04        15
#            1       0.24      0.40      0.30       277
#            2       0.89      0.65      0.75      1616
#
#     accuracy                           0.61      1908
#    macro avg       0.38      0.46      0.36      1908
# weighted avg       0.78      0.61      0.68      1908
#
# [[   5    5    5]
#  [  34  112  131]
#  [ 204  358 1054]]
# Overall Accuracy: 0.61

# %% [markdown]
# #### Random Forest Model - Iteration 4: Hyper-tuning

# %%
# Define parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Instantiate RandomForestClassifier
rf_clf_4 = RandomForestClassifier(random_state=42, class_weight='balanced')

# Instantiate GridSearchCV
grid_search_rf = GridSearchCV(rf_clf_4, param_grid, cv=5, scoring='accuracy', verbose=1, n_jobs=-1)

# Fit the grid search
grid_search_rf.fit(X_train_res, y_train_res)

# Print the best parameters and best score
print("Best parameters found for Random Forest Classifier:")
print(grid_search_rf.best_params_)
print("Best cross-validation accuracy score: {:.2f}".format(grid_search_rf.best_score_))

# Make predictions using the best model
y_pred_rf_4 = grid_search_rf.predict(X_test)

# Evaluate the model
print("Random Forest Classifier Model:")
cr_rf_4 = classification_report(y_test, y_pred_rf_4, zero_division=1)
cm_rf_4 = confusion_matrix(y_test, y_pred_rf_4)
print(cr_rf_4)
print(cm_rf_4)

# Calculate overall accuracy
accuracy_rf_4 = accuracy_score(y_test, y_pred_rf_4)
print(f"Overall Accuracy: {accuracy_rf_4:.2f}")
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Best parameters found for Random Forest Classifier:
# {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Best cross-validation accuracy score: 0.91
# Random Forest Classifier Model:
#               precision    recall  f1-score   support
#
#            0       0.05      0.07      0.06        15
#            1       0.25      0.23      0.24       277
#            2       0.87      0.87      0.87      1616
#
#     accuracy                           0.77      1908
#    macro avg       0.39      0.39      0.39      1908
# weighted avg       0.77      0.77      0.77      1908
#
# [[   1    4   10]
#  [   7   65  205]
#  [  13  196 1407]]
# Overall Accuracy: 0.77

# %% [markdown]
# #### Gradient Boosting Model - Iteration 4: Hyper-tuning

# %%
# Define parameter distributions
param_dist = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.05, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_samples_split': stats.randint(2, 20),
    'min_samples_leaf': stats.randint(1, 20)
}

# Instantiate GradientBoostingClassifier
gb_clf_4 = GradientBoostingClassifier(random_state=42)

# Instantiate RandomizedSearchCV
random_search_gb = RandomizedSearchCV(gb_clf_4, param_distributions=param_dist, n_iter=50, cv=5, scoring='accuracy', random_state=42, verbose=1, n_jobs=-1)

# Fit the random search
random_search_gb.fit(X_train_res, y_train_res)

# Print the best parameters and best score
print("Best parameters found for Gradient Boosting Classifier:")
print(random_search_gb.best_params_)
print("Best cross-validation accuracy score: {:.2f}".format(random_search_gb.best_score_))

# Make predictions using the best model
y_pred_gb_4 = random_search_gb.predict(X_test)

# Evaluate the model
print("Gradient Boosting Classifier Model:")
cr_gb_4 = classification_report(y_test, y_pred_gb_4, zero_division=1)
cm_gb_4 = confusion_matrix(y_test, y_pred_gb_4)
print(cr_gb_4)
print(cm_gb_4)

# Calculate overall accuracy
accuracy_gb_4 = accuracy_score(y_test, y_pred_gb_4)
print(f"Overall Accuracy: {accuracy_gb_4:.2f}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found for Gradient Boosting Classifier:
# {'learning_rate': 0.2, 'max_depth': 7, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 200}
# Best cross-validation accuracy score: 0.91
# Gradient Boosting Classifier Model:
#               precision    recall  f1-score   support
#
#            0       0.07      0.07      0.07        15
#            1       0.27      0.25      0.26       277
#            2       0.87      0.89      0.88      1616
#
#     accuracy                           0.79      1908
#    macro avg       0.40      0.40      0.40      1908
# weighted avg       0.78      0.79      0.78      1908
#
# [[   1    4   10]
#  [   5   68  204]
#  [   9  176 1431]]
# Overall Accuracy: 0.79

# %% [markdown]
# ### Task 6.4 - Model Comparison
#
# Please provide the related code for evaluating the model complexity and performance. Refer to the explanation for the **good** criterion. Note that you need to compare at least two different models based on performance and model complexity. This criterion corresponds to the **good** criterion.

# %%
# Print the best parameters and best score Hyper-tuned Random Forest Classifier
print("Best parameters found for Random Forest Classifier:")
print(grid_search_rf.best_params_)
print("Best cross-validation accuracy score: {:.2f}".format(grid_search_rf.best_score_))

# Evaluate the model
print("Hyper-tuned Random Forest Classifier Model:")
cr_rf_4 = classification_report(y_test, y_pred_rf_4, zero_division=1)
cm_rf_4 = confusion_matrix(y_test, y_pred_rf_4)
print(cr_rf_4)
print(cm_rf_4)

# Calculate overall accuracy
accuracy_rf_4 = accuracy_score(y_test, y_pred_rf_4)
print(f"Overall Accuracy: {accuracy_rf_4:.2f}")

# Evaluate the model
print("\nHyper-tuned Gradient Boosting Classifier Model:")
cr_gb_4 = classification_report(y_test, y_pred_gb_4, zero_division=1)
cm_gb_4 = confusion_matrix(y_test, y_pred_gb_4)
print(cr_gb_4)
print(cm_gb_4)

# Calculate overall accuracy
accuracy_gb_4 = accuracy_score(y_test, y_pred_gb_4)
print(f"Overall Accuracy: {accuracy_gb_4:.2f}")
# Out:
# Hyper-tuned Random Forest Classifier Model:
#               precision    recall  f1-score   support
#
#            0       0.05      0.07      0.06        15
#            1       0.25      0.23      0.24       277
#            2       0.87      0.87      0.87      1616
#
#     accuracy                           0.77      1908
#    macro avg       0.39      0.39      0.39      1908
# weighted avg       0.77      0.77      0.77      1908
#
# [[   1    4   10]
#  [   7   65  205]
#  [  13  196 1407]]
# Overall Accuracy: 0.77
#
# Hyper-tuned Gradient Boosting Classifier Model:
#               precision    recall  f1-score   support
#
#            0       0.07      0.07      0.07        15
#            1       0.27      0.25      0.26       277
#            2       0.87      0.89      0.88      1616
#
#     accuracy                           0.79      1908
#    macro avg       0.40      0.40      0.40      1908
# weighted avg       0.78      0.79      0.78      1908
#
# [[   1    4   10]
# ...

# %% [markdown]
# #### Analysis:
#
# *The Hyper-tuned Random Forest Classifier:*
# - This model has high precision and recall for the majority class (Class 2) but struggles with the minority classes (Class 0 and Class 1).
# - The overall accuracy is good (0.77), but this is primarily due to the performance on the majority class.
# - Model Complexity: Moderate
# - Number of Parameters: The Random Forest model involves multiple decision trees (200 in this case), which can increase the model's complexity and training time, especially with deeper trees (max_depth of 20).
# - Interpretability: Generally lower due to the ensemble of many decision trees, but feature importance can still be extracted to some extent.
#
# *The Hyper-tuned Gradient Boosting Classifier:*
# - This model shows slightly better performance for the minority classes compared to the Random Forest Classifier, especially for Class 1.
# - The overall accuracy is higher (0.79), and the F1-score for Class 1 is better than that of the Random Forest model.
# - Model Complexity: High
# - Number of Parameters: Gradient Boosting builds trees sequentially, each one trying to correct the errors of the previous trees. This process is computationally intensive and requires tuning more hyperparameters (learning rate, max_depth, min_samples_split, etc.).
# - Interpretability: Lower than Random Forest due to the sequential nature of boosting, but partial dependence plots can help understand the effect of features.
#
# #### Conclusion
# Performance:
# - The Gradient Boosting Classifier generally outperforms the Random Forest Classifier in terms of overall accuracy and F1-score for the minority classes, especially Class 1.
# - Both models have similar performance for the majority class (Class 2), but the Gradient Boosting Classifier shows better handling of the minority classes.
#
# #### Model Complexity:
# - The Random Forest Classifier is less complex compared to the Gradient Boosting Classifier, making it easier to train and interpret.
# - The Gradient Boosting Classifier, while more complex and computationally intensive, provides better performance for imbalanced classes.

# %% [markdown]
# ### Task 6.5 - Complex Machine Learning Model
#
# Please provide the corresponding code for the deep machine learning model. For more details, please refer to the **excellent** criterion. For this section, you need to use **Keras** to train a deep machine learning model. This evidence corresponds to the **excellent** criterion.

# %%
# Iteration 1:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE

# Define neural network architecture
model = Sequential([
    Dense(512, input_dim=X_train_res.shape[1]),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(256),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(128),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(64),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(len(np.unique(y_train_res)), activation='softmax')  # Output layer with softmax for multi-class classification
])

# Compile the model
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Set up callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = model.fit(
    X_train_res, y_train_res,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")

# Make predictions
y_pred = np.argmax(model.predict(X_test), axis=-1)

# Evaluate predictions
print("Classification Report:")
print(classification_report(y_test, y_pred, zero_division=1))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/100
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 15s 22ms/step - accuracy: 0.3703 - loss: 1.6050 - val_accuracy: 0.8470 - val_loss: 1.5542 - learning_rate: 0.0010
# Epoch 2/100
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4422 - loss: 1.0995 - val_accuracy: 0.0079 - val_loss: 13.1328 - learning_rate: 0.0010
# Epoch 3/100
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5478 - loss: 0.9361 - val_accuracy: 0.8470 - val_loss: 2.2187 - learning_rate: 0.0010
# Epoch 4/100
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5973 - loss: 0.8739 - val_accuracy: 0.8470 - val_loss: 4.5925 - learning_rate: 0.0010
# Epoch 5/100
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6149 - loss: 0.8486 - val_accuracy: 0.8470 - val_loss: 2.7131 - learning_rate: 0.0010
# Epoch 6/100
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6243 - loss: 0.8263 - val_accuracy: 0.8386 - val_loss: 1.9425 - learning_rate: 0.0010
# Epoch 7/100
# ...

# %%
# Iteration 2:
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from imblearn.over_sampling import SMOTE

# Standardize the data
scaler = StandardScaler()
X_train_res_scaled = scaler.fit_transform(X_train_res)
X_test_scaled = scaler.transform(X_test)

# Define neural network architecture
model = Sequential([
    Dense(512, kernel_regularizer=l2(0.01), input_dim=X_train_res_scaled.shape[1]),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(256, kernel_regularizer=l2(0.01)),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(128, kernel_regularizer=l2(0.01)),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(64, kernel_regularizer=l2(0.01)),
    LeakyReLU(negative_slope=0.1),
    BatchNormalization(),
    Dropout(0.5),

    Dense(len(np.unique(y_train_res)), activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Set up callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = model.fit(
    X_train_res_scaled, y_train_res,
    epochs=100,
    batch_size=64,
    validation_data=(X_test_scaled, y_test),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy}")

# Make predictions
y_pred = np.argmax(model.predict(X_test_scaled), axis=-1)

# Evaluate predictions
print("Classification Report:")
print(classification_report(y_test, y_pred, zero_division=1))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.4918 - loss: 7.1521 - val_accuracy: 0.4030 - val_loss: 5.2218 - learning_rate: 0.0010
# Epoch 2/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6309 - loss: 4.4694 - val_accuracy: 0.4088 - val_loss: 3.3117 - learning_rate: 0.0010
# Epoch 3/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6930 - loss: 2.6946 - val_accuracy: 0.4423 - val_loss: 2.1507 - learning_rate: 0.0010
# Epoch 4/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7343 - loss: 1.7012 - val_accuracy: 0.4953 - val_loss: 1.5645 - learning_rate: 0.0010
# Epoch 5/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7452 - loss: 1.2101 - val_accuracy: 0.5456 - val_loss: 1.2728 - learning_rate: 0.0010
# Epoch 6/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7462 - loss: 1.0014 - val_accuracy: 0.5828 - val_loss: 1.0716 - learning_rate: 0.0010
# Epoch 7/100
# ...

# %% [markdown]
# ## Comparison of the CNN Iterations:

# %% [markdown]
# Comparing the two iterations of CNN models, we observe distinct differences in their architecture, training process, and performance metrics.
#
# In Iteration 1, the model architecture does not include any kernel regularization, and the input data is used without scaling. The model achieved a high test accuracy of 84.7%, but the classification report and confusion matrix indicate severe class imbalance issues, with the model predicting only the majority class (class 2) correctly. The classification report shows a macro average F1-score of 0.31, reflecting poor performance on minority classes.
#
# Iteration 2, on the other hand, incorporates L2 kernel regularization and standardizes the input data, which likely contributed to a more balanced training process. Despite these improvements, the test accuracy dropped to 71.3%. However, the classification report and confusion matrix reveal a better distribution of predictions across classes, with the model showing improved precision and recall for the minority class (class 1). The macro average F1-score increased to 0.37, indicating a more balanced performance across all classes compared to Iteration 1.
#
# In summary, Iteration 1 achieved higher overall accuracy but failed to address class imbalance effectively. Iteration 2 demonstrated improved handling of class imbalance and more balanced performance metrics, though at the cost of reduced overall accuracy. Both iterations highlight the trade-offs between accuracy and balanced class performance in multi-class classification tasks.

# %% [markdown]
# ## ILO 7.0: Deployment
#
# The student is able to deliver value to the stakeholders by delivering production-ready code that is designed to be implemented into practical real-world scenarios such as applications or products.
#
# Delivers value to the stakeholders by providing production-ready code that can be implemented into practical real-world scenarios through a proof of concept deployment:
#
# - **Poor**: Clear Individual contribution is documented. Python scripts are delivered.
#
# - **Insufficient**: Creates a virtual environment and utilizes it alongside a package manager, enabling efficient management of dependencies and packages required for a data science project. And meeting all criteria in poor.
#
# - **Sufficient**: Works towards delivering clean code according to industry standards, for example, by using logging, linting, doc strings, code formatting, refactoring etc. And meeting all criteria in insufficient.
#
# - **Good**: Unit tests are conducted to check the robustness of the delivered code with a test coverage of at least 30%. Industry-standard tools are used to document the code (e.g., sphinx). And meeting all criteria in sufficient.
#
# - **Excellent**: Industry ready applications are created and ready to be deployed. Streamlit or other such tools are used to create user friendly interface, which serves the business objective. And meeting all criteria in good.

# %% [markdown]
# ### Task 7.1 - Python Scripts
#
# Please add Individual Python scripts, and/or the link to your peers' Python scripts, if needed. Links should direct only to your own GitHub repository. This evidence corresponds to the **poor** criterion.

# %%
# Put your code and/or link here.
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/tree/b7facfaadae335d0362dae5ed009ccca8181e5fe/team15project/team15project

# %% [markdown]
# ### Task 7.2 - Virtual Environment
#
# Please provide the link to the requirements.txt file here for Virtual environment. Also add the screenshots of creating the virtual environment and running the code in the virtual environment. This evidence corresponds to the **insufficient** criterion.

# %%
# Put your evidence here
# /root/.local/bin/poetry --version
Poetry (version 1.8.3)
# /root/.local/bin/poetry new team15project
Created package team15project in team15project
# cd team15project
# poetry add ipykernel
/usr/bin/sh: 4: poetry: not found
# root/.local/bin/poetry --version
/usr/bin/sh: 5: root/.local/bin/poetry: not found
# ls
README.md  pyproject.toml  team15project  tests
# cd team15project
# poetry add ipykernel
/usr/bin/sh: 8: poetry: not found
# root/.local/bin/poetry add ipykernel
/usr/bin/sh: 9: root/.local/bin/poetry: not found
# root/.local/bin/poetry install       
/usr/bin/sh: 10: root/.local/bin/poetry: not found
# /root/.local/bin/poetry --version
Poetry (version 1.8.3)
# /root/.local/bin/poetry install 
Creating virtualenv team15project-gbN8r2XJ-py3.11 in /root/.cache/pypoetry/virtualenvs
Updating dependencies
Resolving dependencies... (0.1s)

Writing lock file

Installing the current project: team15project (0.1.0)
# /root/.local/bin/poetry add ipykernel
Using version ^6.29.4 for ipykernel

Updating dependencies
Resolving dependencies... (1.3s)

Package operations: 29 installs, 0 updates, 0 removals

  - Installing six (1.16.0)
  - Installing asttokens (2.4.1)
  - Installing executing (2.0.1)
  - Installing parso (0.8.4)
  - Installing platformdirs (4.2.2)
  - Installing ptyprocess (0.7.0)
  - Installing pure-eval (0.2.2)
  - Installing traitlets (5.14.3)
  - Installing wcwidth (0.2.13)
  - Installing decorator (5.1.1)
  - Installing jedi (0.19.1)
  - Installing jupyter-core (5.7.2)
  - Installing matplotlib-inline (0.1.7)
  - Installing pexpect (4.9.0)
  - Installing prompt-toolkit (3.0.47)
  - Installing pygments (2.18.0)
  - Installing python-dateutil (2.9.0.post0)
  - Installing pyzmq (26.0.3)
  - Installing stack-data (0.6.3)
  - Installing tornado (6.4.1)
  - Installing typing-extensions (4.12.2)
  - Installing comm (0.2.2)
  - Installing debugpy (1.8.1)
  - Installing ipython (8.25.0)
  - Installing jupyter-client (8.6.2)
  - Installing nest-asyncio (1.6.0)
  - Installing packaging (24.1)
  - Installing psutil (5.9.8)
  - Installing ipykernel (6.29.4)

Writing lock file
# /root/.local/bin/poetry run python -m ipykernel install --user --name PoetryEnvironment --display-name "Poetry Environment"
Installed kernelspec PoetryEnvironment in /root/.local/share/jupyter/kernels/poetryenvironment
#

# %%
# Link for the configuration file
https://github.com/BredaUniversityADSAI/2023-24d-fai1-adsai-teamwork-t15/blob/b7facfaadae335d0362dae5ed009ccca8181e5fe/team15project/pyproject.toml

# %% [markdown]
# ### Task 7.3 - Cleaning your code
#
# Please provide an example of how you commneted, and how you structured your code [Linting, Logging, Docstrings etc]. This evidence corresponds to **sufficient** criterion.

# %%
# Put your evidence here

# %% [markdown]
# ### Task 7.4 - Test Coverage
#
# Please provide sample unit test cases and evidence that you managed to meet 30% of the code coverage. This evidence corresponds to **good** criterion.

# %%
# Put your evidence here

# %% [markdown]
# ### Task 7.5 - Production Ready application
#
# Please provide evidence regarding how you intended to deliver this Python application to the end user / client. Examples include Streamlit, Flask, Django, FastAPI, etc. This evidence corresponds to **excellent** criterion.

# %%
# Put your evidence here
